# %%
#### Dependencies

from anytree import Node, NodeMixin, RenderTree
from PIL import Image
from skimage.feature import greycomatrix, greycoprops

import glob
import math
import matplotlib.pyplot as plt
import os
import random

# %%
#### Global variables

model = {}
test_model = {}
map_8bit_to_3bit = [i // 32 for i in range(256)]

# %%
#### Classes

class MyBaseClass(object):
    foo = 4
    
class TreeNode(MyBaseClass, NodeMixin):
    def __init__(self, subset, purity, glcm_index=0, glcm_median=0, dominant_class='', parent=None, children=None):
        super(TreeNode, self).__init__()
        self.subset = subset
        self.purity = purity
        self.glcm_index = glcm_index
        self.glcm_median = glcm_median
        self.dominant_class = dominant_class
        if(not children == None):
            self.children = children

# %%
#### Functions

def load_img(img_path):
    return Image.open(img_path).convert('L')

def get_img_size(img):
    return img.size

def print_img(img):
    plt.imshow(img, cmap='gray')
    
def get_resized_img(img, dimension):
    return img.resize(dimension)

def get_img_colors(img):
    return list(img.getdata())

def get_3bit_img_colors(img):
    img_colors = get_img_colors(img)
    
    loop_count = 0
    for img_color in img_colors:
        img_colors[loop_count] = map_8bit_to_3bit[img_color]
        
        loop_count += 1
        
    return img_colors

def get_img_matrix(img_colors):
    img_matrix = []
    
    loop_count = 0
    img_square_dimension = int(math.sqrt(len(img_colors)))
    
    for row in range(img_square_dimension):
        temp_row = []
        for col in range(img_square_dimension):
            temp_row.append(img_colors[loop_count])
            
            loop_count += 1
        img_matrix.append(temp_row)
        
    return img_matrix

def get_img_features(img):
    img_3bit_colors = get_3bit_img_colors(img)
    img_matrix = get_img_matrix(img_3bit_colors)
    
    glcm_matrix = greycomatrix(img_matrix, distances=[1], angles=[0], levels=12, symmetric=False, normed=False)
    glcm_components = ['contrast', 'correlation', 'energy', 'homogeneity', 'ASM', 'dissimilarity']
    
    img_features = []
    for glcm_component in glcm_components:
        img_features.append(greycoprops(glcm_matrix, glcm_component)[0][0])
        
    return tuple(img_features)

# Modelling

def init_model():
    global model
    global test_model
    
    model = {}
    test_model = {}
    
def get_class_names(training_path):
    return os.listdir(training_path)
    
def get_class_names_in_model():
    class_names = [class_name for class_name in model]
    
    return class_names
    
def add_class_names_to_model(class_names):
    global model
    global test_model
    
    for class_name in class_names:
        if(not class_name in model):
            model[class_name] = []
        if(not class_name in test_model):
            test_model[class_name] = []
            
def insert_img_features_into_model(class_name, img_features):
    global model
    
    if(class_name in model):
        model[class_name].append(img_features)
        
def insert_img_features_into_test_model(class_name, img_features):
    global test_model
    
    if(class_name in test_model):
        test_model[class_name].append(img_features)
        
def load_preprocessed_img(img_path, dimension=(128, 128)):
    img = load_img(img_path)
    img = get_resized_img(img, dimension)
    
    return img

def train(training_path, training_rate=0.8, img_type='*.jpg'):
    print('Training...')
    class_names = get_class_names(training_path)
    for class_name in class_names:
        img_paths = glob.glob(training_path + class_name + '/' + img_type)
        
        for img_path in img_paths:
            random_splitter = random.uniform(0, 1)
            
            img = load_preprocessed_img(img_path)
            img_features = get_img_features(img)
            
            if(random_splitter <= training_rate):
                insert_img_features_into_model(class_name, img_features)
            else:
                insert_img_features_into_test_model(class_name, img_features)
            
    print('--> Done')
    
# Decision Tree Stuffs

def get_normalized_model(model):
    normalized_model = []
    
    for class_name in model:
        for glcm_values in model[class_name]:
            new_row = (class_name, glcm_values[0], glcm_values[1], glcm_values[2], glcm_values[3], glcm_values[4], glcm_values[5])
            normalized_model.append(new_row)
        
    return normalized_model

def get_subset_purity(subset, minimum_purity=0.8):
    if(len(subset) > 0):
        class_names = get_class_names_in_model()
        
        total_class = len(class_names)
        total_class_score = len(subset)
        subset_class_scores = [0 for i in range(total_class)]
        
        for row in subset:
            row_class_name = row[0]
            subset_class_scores[class_names.index(row_class_name)] += 1
            
        subset_purity = 0
        for class_index in range(total_class):
            subset_purity += (subset_class_scores[class_index] / total_class_score) ** 2
            
        dominant_class = ''
        if(subset_purity >= minimum_purity):
            maximum_class_scores = max(subset_class_scores)
            dominant_class_index = subset_class_scores.index(maximum_class_scores)
            dominant_class = class_names[dominant_class_index]
            
        return (subset_purity, dominant_class)
    else:
        return (0, '')
    
def get_tree_seed(model, minimum_purity=0.8):
    normalized_model = get_normalized_model(model)
    tree = TreeNode(normalized_model, get_subset_purity(normalized_model, minimum_purity)[0])
    
    return tree

def get_decision_tree(decision_tree, minimum_purity=0.8, n_branch=2, glcm_length=6):
    if(decision_tree.purity >= minimum_purity or len(decision_tree.subset) == 0):
        return decision_tree
    else:
        subset = decision_tree.subset
        
        class_names = get_class_names_in_model()
        
        branch_future_subset_purities = [[glcm_index, 0] for glcm_index in range(glcm_length)]
        branch_glcm_medians           = [[0 for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_subsets                = [[[] for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_purities               = [[0 for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_dominants              = [['' for glcm_index in range(glcm_length)] for i in range(n_branch)]
        
        for glcm_index in range(glcm_length):
            sorted_subset = sorted(subset, key=lambda x: x[glcm_index + 1])
            sorted_subset_length = len(sorted_subset)
            
            if(sorted_subset_length < n_branch):
                n_branch = sorted_subset_length
                
            row_per_branch = int(sorted_subset_length / n_branch)
            branch_constraint = [row_per_branch * i for i in range(n_branch + 1)]
            branch_constraint[-1] = sorted_subset_length
            
            for branch_index in range(n_branch):
                branch_subsets[branch_index][glcm_index] = sorted_subset[branch_constraint[branch_index]:branch_constraint[branch_index + 1]]
                
                branch_glcm_medians[branch_index][glcm_index] = branch_subsets[branch_index][glcm_index][-1][glcm_index + 1]
                branch_purity_and_dominant = get_subset_purity(branch_subsets[branch_index][glcm_index], minimum_purity)
                branch_purities[branch_index][glcm_index] = branch_purity_and_dominant[0]
                branch_dominants[branch_index][glcm_index] = branch_purity_and_dominant[1]
                
                if(branch_purities[branch_index][glcm_index] >= minimum_purity):
                    branch_future_subset_purities[glcm_index][1] += 1
                    
        sorted_branch_future_subset_purities = sorted(branch_future_subset_purities, key= lambda x: -x[1])
        glcm_index = sorted_branch_future_subset_purities[0][0]
            
        for branch_index in range(n_branch):
            branch_subset = branch_subsets[branch_index][glcm_index]
            branch_purity = branch_purities[branch_index][glcm_index]
            branch_glcm_median = branch_glcm_medians[branch_index][glcm_index]
            branch_dominant = branch_dominants[branch_index][glcm_index]
                
            decision_tree_branch = TreeNode(branch_subset, branch_purity, glcm_index, branch_glcm_median, branch_dominant)
            decision_tree_branch = get_decision_tree(decision_tree_branch, minimum_purity, n_branch)
                
            if(not decision_tree_branch == None):
                decision_tree_branch.parent = decision_tree
            
        return decision_tree
    
def print_decision_tree(decision_tree):
    print(RenderTree(decision_tree))
    
def get_img_features_class(img_features, decision_tree, minimum_purity=0.8):
    temp_decision_tree = decision_tree
    
    while(temp_decision_tree.purity < minimum_purity and not temp_decision_tree.children == ()):
        childrens = temp_decision_tree.children
        total_childs = len(childrens)
        
        is_glcm_median_not_available = True
        child_index = 0
        for children in childrens:
            glcm_index = children.glcm_index
            glcm_median = children.glcm_median
            
            if(img_features[glcm_index] <= glcm_median):
                is_glcm_median_not_available = False
                break
                
            child_index += 1
                
        if(child_index >= total_childs):
            temp_decision_tree = childrens[-1]
        else:
            temp_decision_tree = childrens[child_index]
            
    img_class_name = temp_decision_tree.dominant_class
    
    return img_class_name
    
def get_img_class(img, decision_tree, minimum_purity=0.8):
    img_features = get_img_features(img)
            
    img_class_name = get_img_features_class(img_features, decision_tree, minimum_purity)
    
    return img_class_name

def test(decision_tree, minimum_purity=0.8):
    print('Testing...')
    class_name = get_class_names_in_model()
    total_correct_answer = 0
    total_guess = 0
    
    for class_name in test_model:
        for test_img_features in test_model[class_name]:
            test_img_class_name = get_img_features_class(test_img_features, decision_tree, minimum_purity)
            
            if(class_name == test_img_class_name):
                total_correct_answer += 1
                
            total_guess += 1
            
    accuracy = (total_correct_answer / total_guess) * 100
    
    print('--> Done, accuracy = ' + str(accuracy) + ' %')
    
    return accuracy
        

def validate(validation_path, decision_tree, minimum_purity=0.8, img_type='*.jpg'):
    print('Validating...')
    class_names = get_class_names_in_model()
    total_correct_answer = 0
    total_guess = 0
    
    for class_name in class_names:
        img_paths = glob.glob(validation_path + class_name + '/' + img_type)
        for img_path in img_paths:
            img = load_preprocessed_img(img_path)
            img_class_name = get_img_class(img, decision_tree, minimum_purity)
            
            if(class_name == img_class_name):
                total_correct_answer += 1
                
            total_guess += 1
            
    print('--> Done')
    
    accuracy = (total_correct_answer / total_guess) * 100
    
    return accuracy

# %%
#### Main

# Defining paths
root_path       = './'
training_path   = root_path + 'training/'
validation_path = root_path + 'validation/'
test_path       = root_path + 'test/'

# Props
epochs = 5
training_rate = 0.80
img_type = '*.jpg'
n_branch = 4
minimum_purity = 0.95

# Init
init_model()
class_names = get_class_names(training_path)
add_class_names_to_model(class_names)

for epoch in range(epochs):
    print('Epoch ' + str(epoch + 1))
    train(training_path, training_rate, img_type)
    dtree_seed = get_tree_seed(model, minimum_purity)
    dtree = get_decision_tree(dtree_seed, minimum_purity, n_branch)
    test(dtree, minimum_purity)
    print()

model_accuracy = validate(validation_path, dtree, minimum_purity, img_type)

print(model_accuracy)
# Out:
# Epoch 1
# Training...
# --> Done
# Testing...
# --> Done, accuracy = 87.25490196078431 %
#
# Epoch 2
# Training...
# --> Done
# Testing...
# --> Done, accuracy = 96.74418604651163 %
#
# Epoch 3
# Training...
# --> Done
# Testing...
# --> Done, accuracy = 98.78048780487805 %
#
# Epoch 4
# Training...
# --> Done
# Testing...
# --> Done, accuracy = 100.0 %
#
# Epoch 5
# Training...
# --> Done
# Testing...
# --> Done, accuracy = 100.0 %
#
# Validating...
# --> Done
# 89.84375

# %%
print_decision_tree(dtree)
# Out:
# <__main__.TreeNode object at 0x0000014E799A3D88>
# ├── <__main__.TreeNode object at 0x0000014E79310108>
# │   ├── <__main__.TreeNode object at 0x0000014E7984AB48>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A50488>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A56CC8>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A56A48>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A56908>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB1E88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB1FC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB1F88>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB3088>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB1F48>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A48C48>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A48788>
# │   │   └── <__main__.TreeNode object at 0x0000014E79A48F08>
# │   ├── <__main__.TreeNode object at 0x0000014E79A2EDC8>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A45808>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A50548>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A50308>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A50FC8>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79A50D88>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB3708>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB3848>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB3888>
# │   │   │       └── <__main__.TreeNode object at 0x0000014E79AB38C8>
# │   │   ├── <__main__.TreeNode object at 0x0000014E7927DE08>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A45A88>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A567C8>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A56408>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79A56608>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB3CC8>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB3E08>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB3E48>
# │   │   │       └── <__main__.TreeNode object at 0x0000014E79AB3E88>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A56A88>
# │   │   └── <__main__.TreeNode object at 0x0000014E79A56508>
# │   ├── <__main__.TreeNode object at 0x0000014E799F68C8>
# │   └── <__main__.TreeNode object at 0x0000014E799F6088>
# ├── <__main__.TreeNode object at 0x0000014E799A7548>
# │   ├── <__main__.TreeNode object at 0x0000014E79855F08>
# │   │   ├── <__main__.TreeNode object at 0x0000014E799F6F88>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A2D308>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A2E188>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB1988>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB1A48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB7688>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB89C8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB8A48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB7D88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB7A08>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB7A88>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB3F08>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB3EC8>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB7748>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB7448>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB7488>
# │   │   │       └── <__main__.TreeNode object at 0x0000014E79AB74C8>
# │   │   │           ├── <__main__.TreeNode object at 0x0000014E79AB8EC8>
# │   │   │           ├── <__main__.TreeNode object at 0x0000014E79AB8F48>
# │   │   │           └── <__main__.TreeNode object at 0x0000014E79AB8F88>
# │   │   └── <__main__.TreeNode object at 0x0000014E79A48088>
# │   ├── <__main__.TreeNode object at 0x0000014E79856188>
# │   │   ├── <__main__.TreeNode object at 0x0000014E799F63C8>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A2DBC8>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A3C9C8>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A3CA88>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A4FE88>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79A4FBC8>
# │   │   ├── <__main__.TreeNode object at 0x0000014E7927D888>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A4FB08>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A4F648>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB7048>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79ABEA48>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79ABEAC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB8D88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB88C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB7588>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB39C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB15C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB1B48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB1C48>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB1308>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB37C8>
# │   │   └── <__main__.TreeNode object at 0x0000014E793A29C8>
# │   ├── <__main__.TreeNode object at 0x0000014E792FC5C8>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A45908>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E7979E7C8>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E7979EB88>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E7979E788>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79A506C8>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79855A48>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E7927D748>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB7A48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB7908>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB7EC8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AC08C8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79AC0948>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79ABEC88>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E7927D308>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E7927D988>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB71C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB7988>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB1B88>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB1248>
# │   │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AC0D48>
# │   │   │   │       └── <__main__.TreeNode object at 0x0000014E79AC0DC8>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB7108>
# │   │   ├── <__main__.TreeNode object at 0x0000014E7979EC08>
# │   │   └── <__main__.TreeNode object at 0x0000014E79A45448>
# │   └── <__main__.TreeNode object at 0x0000014E7979EC88>
# │       ├── <__main__.TreeNode object at 0x0000014E799FF5C8>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB8408>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB8B08>
# │       │   │   ├── <__main__.TreeNode object at 0x0000014E79A2EBC8>
# │       │   │   ├── <__main__.TreeNode object at 0x0000014E79A2E3C8>
# │       │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AC4548>
# │       │   │   │   └── <__main__.TreeNode object at 0x0000014E79AC45C8>
# │       │   │   ├── <__main__.TreeNode object at 0x0000014E79AC0488>
# │       │   │   └── <__main__.TreeNode object at 0x0000014E79AC0F08>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB8B88>
# │       │   └── <__main__.TreeNode object at 0x0000014E79AB8FC8>
# │       │       ├── <__main__.TreeNode object at 0x0000014E79ABE308>
# │       │       │   ├── <__main__.TreeNode object at 0x0000014E79AC48C8>
# │       │       │   └── <__main__.TreeNode object at 0x0000014E79AC4948>
# │       │       ├── <__main__.TreeNode object at 0x0000014E79AB7288>
# │       │       ├── <__main__.TreeNode object at 0x0000014E79AB1EC8>
# │       │       └── <__main__.TreeNode object at 0x0000014E79ABE948>
# │       ├── <__main__.TreeNode object at 0x0000014E79A4FB48>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB3208>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB3A88>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB3908>
# │       │   └── <__main__.TreeNode object at 0x0000014E79AB34C8>
# │       │       ├── <__main__.TreeNode object at 0x0000014E79AB8D48>
# │       │       ├── <__main__.TreeNode object at 0x0000014E79AB8CC8>
# │       │       ├── <__main__.TreeNode object at 0x0000014E79AB8648>
# │       │       └── <__main__.TreeNode object at 0x0000014E79ABE788>
# │       ├── <__main__.TreeNode object at 0x0000014E79A2D888>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB8BC8>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB8C88>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB8508>
# │       │   │   ├── <__main__.TreeNode object at 0x0000014E79ABE208>
# │       │   │   ├── <__main__.TreeNode object at 0x0000014E79ABE288>
# │       │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AC75C8>
# │       │   │   │   └── <__main__.TreeNode object at 0x0000014E79AC7648>
# │       │   │   ├── <__main__.TreeNode object at 0x0000014E79AC4908>
# │       │   │   └── <__main__.TreeNode object at 0x0000014E79AC4D88>
# │       │   └── <__main__.TreeNode object at 0x0000014E79AB3688>
# │       └── <__main__.TreeNode object at 0x0000014E79A50048>
# ├── <__main__.TreeNode object at 0x0000014E79323C48>
# │   ├── <__main__.TreeNode object at 0x0000014E798C5948>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A4FD88>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AC0C88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A56F08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A568C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A56E08>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79A56308>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79ABEE88>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79ABE108>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79ABE1C8>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB8248>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB8088>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AB8C08>
# │   │   │       └── <__main__.TreeNode object at 0x0000014E79AB8F08>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A2D6C8>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB3188>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB3B08>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB3D88>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79AB3248>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79AB1788>
# │   │   └── <__main__.TreeNode object at 0x0000014E79AB1548>
# │   ├── <__main__.TreeNode object at 0x0000014E79A48208>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A452C8>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A45BC8>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AC0648>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79822C48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A07F48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A07F88>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79A077C8>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79842808>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A0A1C8>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79A0A4C8>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AC0288>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AC0B48>
# │   │   │       ├── <__main__.TreeNode object at 0x0000014E79AC0608>
# │   │   │       └── <__main__.TreeNode object at 0x0000014E79AC0248>
# │   │   ├── <__main__.TreeNode object at 0x0000014E78F64148>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79AB16C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A0A788>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A07A48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A07348>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E799FFDC8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x0000014E799FF208>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79620888>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A45D48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A0A588>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E799FF348>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x0000014E799FFB88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A50A08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A02508>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E79A07408>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E794D8948>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E799C7F88>
# │   │   └── <__main__.TreeNode object at 0x0000014E79AB7248>
# │   ├── <__main__.TreeNode object at 0x0000014E79A4F988>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79AB73C8>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79AB7E08>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79ABE6C8>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79ABE548>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E799FFD08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E799FA588>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E799F6AC8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x0000014E799F6B08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x0000014E799FA348>
# │   │   │   │   └── <__main__.TreeNode object at 0x0000014E799FA788>
# │   │   │   ├── <__main__.TreeNode object at 0x0000014E79A0A5C8>
# │   │   │   └── <__main__.TreeNode object at 0x0000014E79A0A748>
# │   │   ├── <__main__.TreeNode object at 0x0000014E79A2E548>
# │   │   └── <__main__.TreeNode object at 0x0000014E79A2E108>
# │   │       ├── <__main__.TreeNode object at 0x0000014E79AB3508>
# │   │       │   ├── <__main__.TreeNode object at 0x0000014E799FF588>
# │   │       │   ├── <__main__.TreeNode object at 0x0000014E799FFE88>
# │   │       │   ├── <__main__.TreeNode object at 0x0000014E799FFF08>
# │   │       │   │   ├── <__main__.TreeNode object at 0x0000014E799E42C8>
# │   │       │   │   └── <__main__.TreeNode object at 0x0000014E799E4DC8>
# │   │       │   └── <__main__.TreeNode object at 0x0000014E78FB6E08>
# │   │       ├── <__main__.TreeNode object at 0x0000014E79A50288>
# │   │       ├── <__main__.TreeNode object at 0x0000014E79A50108>
# │   │       │   ├── <__main__.TreeNode object at 0x0000014E79A07108>
# │   │       │   ├── <__main__.TreeNode object at 0x0000014E79A07048>
# │   │       │   ├── <__main__.TreeNode object at 0x0000014E79A02A88>
# │   │       │   └── <__main__.TreeNode object at 0x0000014E79A02B48>
# │   │       └── <__main__.TreeNode object at 0x0000014E79A07B88>
# │   └── <__main__.TreeNode object at 0x0000014E79A48388>
# │       ├── <__main__.TreeNode object at 0x0000014E79A56488>
# │       ├── <__main__.TreeNode object at 0x0000014E79A56A08>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79A50608>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79A50248>
# │       │   │   ├── <__main__.TreeNode object at 0x0000014E799F6D08>
# │       │   │   ├── <__main__.TreeNode object at 0x0000014E799F6BC8>
# │       │   │   ├── <__main__.TreeNode object at 0x0000014E79AB84C8>
# │       │   │   └── <__main__.TreeNode object at 0x0000014E79AB8548>
# │       │   │       ├── <__main__.TreeNode object at 0x0000014E799DCCC8>
# │       │   │       └── <__main__.TreeNode object at 0x0000014E799DC9C8>
# │       │   ├── <__main__.TreeNode object at 0x0000014E79AB3DC8>
# │       │   └── <__main__.TreeNode object at 0x0000014E799F6208>
# │       ├── <__main__.TreeNode object at 0x0000014E79A0A188>
# │       └── <__main__.TreeNode object at 0x0000014E79A0A148>
# │           ├── <__main__.TreeNode object at 0x0000014E79A50088>
# │           ├── <__main__.TreeNode object at 0x0000014E79A07988>
# │           │   ├── <__main__.TreeNode object at 0x0000014E799F6808>
# │           │   ├── <__main__.TreeNode object at 0x0000014E799F6648>
# │           │   ├── <__main__.TreeNode object at 0x0000014E799F6308>
# │           │   └── <__main__.TreeNode object at 0x0000014E799F6288>
# │           ├── <__main__.TreeNode object at 0x0000014E79A56708>
# │           └── <__main__.TreeNode object at 0x0000014E79AB1708>
# └── <__main__.TreeNode object at 0x0000014E79811888>
#     ├── <__main__.TreeNode object at 0x0000014E79A4FF88>
#     ├── <__main__.TreeNode object at 0x0000014E79A3CC48>
#     ├── <__main__.TreeNode object at 0x0000014E79A3C908>
#     │   ├── <__main__.TreeNode object at 0x0000014E79A3A388>
#     │   │   ├── <__main__.TreeNode object at 0x0000014E79A02548>
#     │   │   ├── <__main__.TreeNode object at 0x0000014E799E4B08>
#     │   │   ├── <__main__.TreeNode object at 0x0000014E799E4BC8>
#     │   │   └── <__main__.TreeNode object at 0x0000014E799E40C8>
#     │   │       ├── <__main__.TreeNode object at 0x0000014E799DC588>
#     │   │       ├── <__main__.TreeNode object at 0x0000014E799DC508>
#     │   │       ├── <__main__.TreeNode object at 0x0000014E799DC908>
#     │   │       └── <__main__.TreeNode object at 0x0000014E799DCD88>
#     │   ├── <__main__.TreeNode object at 0x0000014E79A02088>
#     │   ├── <__main__.TreeNode object at 0x0000014E79A02448>
#     │   └── <__main__.TreeNode object at 0x0000014E79A02C88>
#     └── <__main__.TreeNode object at 0x0000014E79A45188>
#         ├── <__main__.TreeNode object at 0x0000014E79AB7D08>
#         ├── <__main__.TreeNode object at 0x0000014E79AB7C48>
#         ├── <__main__.TreeNode object at 0x0000014E79AB7888>
#         └── <__main__.TreeNode object at 0x0000014E79AB7188>
#             ├── <__main__.TreeNode object at 0x0000014E799FA088>
#             ├── <__main__.TreeNode object at 0x0000014E799FA4C8>
#             ├── <__main__.TreeNode object at 0x0000014E799FAB08>
#             │   ├── <__main__.TreeNode object at 0x0000014E799DC648>
#             │   ├── <__main__.TreeNode object at 0x0000014E799DCD48>
#             │   ├── <__main__.TreeNode object at 0x0000014E799DCFC8>
#             │   └── <__main__.TreeNode object at 0x0000014E799DC708>
#             └── <__main__.TreeNode object at 0x0000014E79A07648>

# %%
img = load_img(test_path + 'cap.jpg')
print(get_img_class(img, dtree, minimum_purity))
# test correct
# Out:
# cap

# %%
img = load_img(test_path + 'cap2.jpg')
print(get_img_class(img, dtree, minimum_purity))
# test false
# Out:
# tulis

# %%
img = load_img(test_path + 'tulis.jpg')
print(get_img_class(img, dtree, minimum_purity))
# test correct
# Out:
# tulis
