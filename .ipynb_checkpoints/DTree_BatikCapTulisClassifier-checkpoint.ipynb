# %%
#### Dependencies

from anytree import Node, NodeMixin, RenderTree
from PIL import Image
from skimage.feature import greycomatrix, greycoprops

import glob
import math
import matplotlib.pyplot as plt
import os

# %%
#### Global variables

model = {}
map_8bit_to_3bit = [i // 32 for i in range(256)]

# %%
#### Classes

class MyBaseClass(object):
    foo = 4
    
class TreeNode(MyBaseClass, NodeMixin):
    def __init__(self, subset, purity, glcm_index=0, glcm_median=0, dominant_class='', parent=None, children=None):
        super(TreeNode, self).__init__()
        self.subset = subset
        self.purity = purity
        self.glcm_index = glcm_index
        self.glcm_median = glcm_median
        self.dominant_class = dominant_class
        if(not children == None):
            self.children = children

# %%
#### Functions

def load_img(img_path):
    return Image.open(img_path).convert('L')

def get_img_size(img):
    return img.size

def print_img(img):
    plt.imshow(img, cmap='gray')
    
def get_resized_img(img, dimension):
    return img.resize(dimension)

def get_img_colors(img):
    return list(img.getdata())

def get_3bit_img_colors(img):
    img_colors = get_img_colors(img)
    
    loop_count = 0
    for img_color in img_colors:
        img_colors[loop_count] = map_8bit_to_3bit[img_color]
        
        loop_count += 1
        
    return img_colors

def get_img_matrix(img_colors):
    img_matrix = []
    
    loop_count = 0
    img_square_dimension = int(math.sqrt(len(img_colors)))
    
    for row in range(img_square_dimension):
        temp_row = []
        for col in range(img_square_dimension):
            temp_row.append(img_colors[loop_count])
            
            loop_count += 1
        img_matrix.append(temp_row)
        
    return img_matrix

def get_img_features(img):
    img_3bit_colors = get_3bit_img_colors(img)
    img_matrix = get_img_matrix(img_3bit_colors)
    
    glcm_matrix = greycomatrix(img_matrix, distances=[1], angles=[0], levels=12, symmetric=False, normed=False)
    glcm_components = ['contrast', 'correlation', 'energy', 'homogeneity', 'ASM', 'dissimilarity']
    
    img_features = []
    for glcm_component in glcm_components:
        img_features.append(greycoprops(glcm_matrix, glcm_component)[0][0])
        
    return tuple(img_features)

# Modelling

def init_model():
    global model
    
    model = {}
    
def get_class_names(training_path):
    return os.listdir(training_path)
    
def get_class_names_in_model():
    class_names = [class_name for class_name in model]
    
    return class_names
    
def add_class_names_to_model(class_names):
    global model
    
    for class_name in class_names:
        if(not class_name in model):
            model[class_name] = []
            
def insert_img_features_to_model(class_name, img_features):
    global model
    
    if(class_name in model):
        model[class_name].append(img_features)
        
def load_preprocessed_img(img_path, dimension=(128, 128)):
    img = load_img(img_path)
    img = get_resized_img(img, dimension)
    
    return img

def train(training_path, img_type='*.jpg'):
    print('Training...')
    class_names = get_class_names(training_path)
    for class_name in class_names:
        img_paths = glob.glob(training_path + class_name + '/' + img_type)
        
        for img_path in img_paths:
            img = load_preprocessed_img(img_path)
            img_features = get_img_features(img)
            
            insert_img_features_to_model(class_name, img_features)
            
    print('--> Done')
    
# Decision Tree Stuffs

def get_normalized_model(model):
    normalized_model = []
    
    for class_name in model:
        for glcm_values in model[class_name]:
            new_row = (class_name, glcm_values[0], glcm_values[1], glcm_values[2], glcm_values[3], glcm_values[4], glcm_values[5])
            normalized_model.append(new_row)
        
    return normalized_model

def get_subset_purity(subset, minimum_purity=0.8):
    if(len(subset) > 0):
        class_names = get_class_names_in_model()
        
        total_class = len(class_names)
        total_class_score = len(subset)
        subset_class_scores = [0 for i in range(total_class)]
        
        for row in subset:
            row_class_name = row[0]
            subset_class_scores[class_names.index(row_class_name)] += 1
            
        subset_purity = 0
        for class_index in range(total_class):
            subset_purity += (subset_class_scores[class_index] / total_class_score) ** 2
            
        dominant_class = ''
        if(subset_purity >= minimum_purity):
            maximum_class_scores = max(subset_class_scores)
            dominant_class_index = subset_class_scores.index(maximum_class_scores)
            dominant_class = class_names[dominant_class_index]
            
        return (subset_purity, dominant_class)
    else:
        return (0, '')
    
def get_tree_seed(model, minimum_purity=0.8):
    normalized_model = get_normalized_model(model)
    tree = TreeNode(normalized_model, get_subset_purity(normalized_model, minimum_purity)[0])
    
    return tree

def get_decision_tree(decision_tree, minimum_purity=0.8, n_branch=2, glcm_length=6):
    if(decision_tree.purity >= minimum_purity or len(decision_tree.subset) == 0):
        return decision_tree
    else:
        subset = decision_tree.subset
        
        class_names = get_class_names_in_model()
        
        branch_future_subset_purities = [[glcm_index, 0] for glcm_index in range(glcm_length)]
        branch_glcm_medians           = [[0 for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_subsets                = [[[] for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_purities               = [[0 for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_dominants              = [['' for glcm_index in range(glcm_length)] for i in range(n_branch)]
        
        for glcm_index in range(glcm_length):
            sorted_subset = sorted(subset, key=lambda x: x[glcm_index + 1])
            sorted_subset_length = len(sorted_subset)
            
            if(sorted_subset_length < n_branch):
                n_branch = sorted_subset_length
                
            row_per_branch = int(sorted_subset_length / n_branch)
            branch_constraint = [row_per_branch * i for i in range(n_branch + 1)]
            branch_constraint[-1] = sorted_subset_length
            
            for branch_index in range(n_branch):
                branch_subsets[branch_index][glcm_index] = sorted_subset[branch_constraint[branch_index]:branch_constraint[branch_index + 1]]
                
                branch_glcm_medians[branch_index][glcm_index] = branch_subsets[branch_index][glcm_index][-1][glcm_index + 1]
                branch_purity_and_dominant = get_subset_purity(branch_subsets[branch_index][glcm_index], minimum_purity)
                branch_purities[branch_index][glcm_index] = branch_purity_and_dominant[0]
                branch_dominants[branch_index][glcm_index] = branch_purity_and_dominant[1]
                
                if(branch_purities[branch_index][glcm_index] >= minimum_purity):
                    branch_future_subset_purities[glcm_index][1] += 1
                    
        sorted_branch_future_subset_purities = sorted(branch_future_subset_purities, key= lambda x: -x[1])
        glcm_index = sorted_branch_future_subset_purities[0][0]
            
        for branch_index in range(n_branch):
            branch_subset = branch_subsets[branch_index][glcm_index]
            branch_purity = branch_purities[branch_index][glcm_index]
            branch_glcm_median = branch_glcm_medians[branch_index][glcm_index]
            branch_dominant = branch_dominants[branch_index][glcm_index]
                
            decision_tree_branch = TreeNode(branch_subset, branch_purity, glcm_index, branch_glcm_median, branch_dominant)
            decision_tree_branch = get_decision_tree(decision_tree_branch, minimum_purity, n_branch)
                
            if(not decision_tree_branch == None):
                decision_tree_branch.parent = decision_tree
            
        return decision_tree
    
def print_decision_tree(decision_tree):
    print(RenderTree(decision_tree))
    
def get_img_class(img, decision_tree, minimum_purity=0.8):
    img_features = get_img_features(img)
    
    temp_decision_tree = decision_tree
    
    while(temp_decision_tree.purity < minimum_purity and not temp_decision_tree.children == ()):
        childrens = temp_decision_tree.children
        total_childs = len(childrens)
        
        is_glcm_median_not_available = True
        child_index = 0
        for children in childrens:
            glcm_index = children.glcm_index
            glcm_median = children.glcm_median
            
            if(img_features[glcm_index] <= glcm_median):
                is_glcm_median_not_available = False
                break
                
            child_index += 1
                
        if(child_index >= total_childs):
            temp_decision_tree = childrens[-1]
        else:
            temp_decision_tree = childrens[child_index]
            
    img_class_name = temp_decision_tree.dominant_class
    
    return img_class_name

def validate(validation_folder_path, decision_tree, minimum_purity=0.8, img_type='*.jpg'):
    print('Validating...')
    class_names = get_class_names_in_model()
    total_correct_answer = 0
    total_guess = 0
    
    for class_name in class_names:
        img_paths = glob.glob(training_path + class_name + '/' + img_type)
        for img_path in img_paths:
            img = load_preprocessed_img(img_path)
            img_class_name = get_img_class(img, decision_tree, minimum_purity)
            
            if(class_name == img_class_name):
                total_correct_answer += 1
                
            total_guess += 1
            
    print('--> Done')
    
    accuracy = (total_correct_answer / total_guess) * 100
    
    return accuracy

# %%
#### Main

# Defining paths
root_path       = './'
training_path   = root_path + 'training/'
validation_path = root_path + 'validation/'
test_path       = root_path + 'test/'

# Props
img_type = '*.jpg'
n_branch = 2
minimum_purity = 0.95

# Init
init_model()
class_names = get_class_names(training_path)
add_class_names_to_model(class_names)

train(training_path, img_type)

dtree_seed = get_tree_seed(model, minimum_purity)
dtree = get_decision_tree(dtree_seed, minimum_purity, n_branch)

model_accuracy = validate(validation_path, dtree, minimum_purity, img_type)

print(model_accuracy)
# Out:
# Training...
# --> Done
# Validating...
# --> Done
# 99.81343283582089

# %%
print_decision_tree(dtree)
# Out:
# <__main__.TreeNode object at 0x00000298CD701708>
# ├── <__main__.TreeNode object at 0x00000298CE755A08>
# │   ├── <__main__.TreeNode object at 0x00000298CE7C3AC8>
# │   │   ├── <__main__.TreeNode object at 0x00000298CD6E2148>
# │   │   │   ├── <__main__.TreeNode object at 0x00000298CE767948>
# │   │   │   │   ├── <__main__.TreeNode object at 0x00000298CE97B0C8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x00000298CE84FAC8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x00000298CE84FA08>
# │   │   │   │   └── <__main__.TreeNode object at 0x00000298CE984588>
# │   │   │   │       ├── <__main__.TreeNode object at 0x00000298CE84F308>
# │   │   │   │       │   ├── <__main__.TreeNode object at 0x00000298CE935108>
# │   │   │   │       │   │   ├── <__main__.TreeNode object at 0x00000298CE7CBB88>
# │   │   │   │       │   │   └── <__main__.TreeNode object at 0x00000298CE7CBCC8>
# │   │   │   │       │   │       ├── <__main__.TreeNode object at 0x00000298CE996888>
# │   │   │   │       │   │       └── <__main__.TreeNode object at 0x00000298CE996A48>
# │   │   │   │       │   └── <__main__.TreeNode object at 0x00000298CD6A34C8>
# │   │   │   │       └── <__main__.TreeNode object at 0x00000298CE84F508>
# │   │   │   └── <__main__.TreeNode object at 0x00000298CD6CDB08>
# │   │   │       ├── <__main__.TreeNode object at 0x00000298CE767DC8>
# │   │   │       │   ├── <__main__.TreeNode object at 0x00000298CE767108>
# │   │   │       │   └── <__main__.TreeNode object at 0x00000298CE7677C8>
# │   │   │       │       ├── <__main__.TreeNode object at 0x00000298CE984C48>
# │   │   │       │       └── <__main__.TreeNode object at 0x00000298CE984D08>
# │   │   │       └── <__main__.TreeNode object at 0x00000298CD6C6508>
# │   │   └── <__main__.TreeNode object at 0x00000298CE864D48>
# │   └── <__main__.TreeNode object at 0x00000298CE739788>
# │       ├── <__main__.TreeNode object at 0x00000298CE774D08>
# │       │   ├── <__main__.TreeNode object at 0x00000298CE750C48>
# │       │   │   ├── <__main__.TreeNode object at 0x00000298CD6CD408>
# │       │   │   └── <__main__.TreeNode object at 0x00000298CE97B288>
# │       │   │       ├── <__main__.TreeNode object at 0x00000298CE767308>
# │       │   │       │   ├── <__main__.TreeNode object at 0x00000298CE84F488>
# │       │   │       │   │   ├── <__main__.TreeNode object at 0x00000298CE9969C8>
# │       │   │       │   │   └── <__main__.TreeNode object at 0x00000298CE9966C8>
# │       │   │       │   └── <__main__.TreeNode object at 0x00000298CE7CBFC8>
# │       │   │       └── <__main__.TreeNode object at 0x00000298CE9845C8>
# │       │   │           ├── <__main__.TreeNode object at 0x00000298CE84FF88>
# │       │   │           └── <__main__.TreeNode object at 0x00000298CE84FC48>
# │       │   │               ├── <__main__.TreeNode object at 0x00000298CE7A7B48>
# │       │   │               └── <__main__.TreeNode object at 0x00000298CE7A7D48>
# │       │   └── <__main__.TreeNode object at 0x00000298CE864948>
# │       │       ├── <__main__.TreeNode object at 0x00000298CD6CD4C8>
# │       │       │   ├── <__main__.TreeNode object at 0x00000298CE9A2AC8>
# │       │       │   │   ├── <__main__.TreeNode object at 0x00000298CE767248>
# │       │       │   │   └── <__main__.TreeNode object at 0x00000298CE767C48>
# │       │       │   └── <__main__.TreeNode object at 0x00000298CE726D08>
# │       │       └── <__main__.TreeNode object at 0x00000298CE9A2448>
# │       │           ├── <__main__.TreeNode object at 0x00000298CE750E88>
# │       │           └── <__main__.TreeNode object at 0x00000298CE767E48>
# │       │               ├── <__main__.TreeNode object at 0x00000298CE984F88>
# │       │               │   ├── <__main__.TreeNode object at 0x00000298CE99C648>
# │       │               │   │   ├── <__main__.TreeNode object at 0x00000298CE99E588>
# │       │               │   │   └── <__main__.TreeNode object at 0x00000298CE99E108>
# │       │               │   └── <__main__.TreeNode object at 0x00000298CE94C208>
# │       │               │       ├── <__main__.TreeNode object at 0x00000298CE99ED08>
# │       │               │       └── <__main__.TreeNode object at 0x00000298CE99E6C8>
# │       │               └── <__main__.TreeNode object at 0x00000298CE84F148>
# │       └── <__main__.TreeNode object at 0x00000298CD6C6088>
# │           ├── <__main__.TreeNode object at 0x00000298CD6DFB48>
# │           │   ├── <__main__.TreeNode object at 0x00000298CD6DA208>
# │           │   │   ├── <__main__.TreeNode object at 0x00000298CE97BD88>
# │           │   │   │   ├── <__main__.TreeNode object at 0x00000298CE767348>
# │           │   │   │   └── <__main__.TreeNode object at 0x00000298CE767288>
# │           │   │   │       ├── <__main__.TreeNode object at 0x00000298CE84F388>
# │           │   │   │       └── <__main__.TreeNode object at 0x00000298CE99C0C8>
# │           │   │   │           ├── <__main__.TreeNode object at 0x00000298CE86D0C8>
# │           │   │   │           └── <__main__.TreeNode object at 0x00000298CE86D288>
# │           │   │   └── <__main__.TreeNode object at 0x00000298CE7CB308>
# │           │   │       ├── <__main__.TreeNode object at 0x00000298CE97BAC8>
# │           │   │       └── <__main__.TreeNode object at 0x00000298CE97B888>
# │           │   │           ├── <__main__.TreeNode object at 0x00000298CE996DC8>
# │           │   │           └── <__main__.TreeNode object at 0x00000298CE996588>
# │           │   └── <__main__.TreeNode object at 0x00000298CD622548>
# │           └── <__main__.TreeNode object at 0x00000298CE8682C8>
# │               ├── <__main__.TreeNode object at 0x00000298CE7C3C88>
# │               │   ├── <__main__.TreeNode object at 0x00000298CE9A2F88>
# │               │   └── <__main__.TreeNode object at 0x00000298CE9A2E48>
# │               │       ├── <__main__.TreeNode object at 0x00000298CE984248>
# │               │       │   ├── <__main__.TreeNode object at 0x00000298CE767748>
# │               │       │   └── <__main__.TreeNode object at 0x00000298CE7678C8>
# │               │       └── <__main__.TreeNode object at 0x00000298CE97B988>
# │               │           ├── <__main__.TreeNode object at 0x00000298CE99EE88>
# │               │           └── <__main__.TreeNode object at 0x00000298CE99E0C8>
# │               │               ├── <__main__.TreeNode object at 0x00000298CE97C2C8>
# │               │               └── <__main__.TreeNode object at 0x00000298CE729688>
# │               └── <__main__.TreeNode object at 0x00000298CE774C48>
# │                   ├── <__main__.TreeNode object at 0x00000298CE8680C8>
# │                   │   ├── <__main__.TreeNode object at 0x00000298CE7501C8>
# │                   │   │   ├── <__main__.TreeNode object at 0x00000298CE99E788>
# │                   │   │   └── <__main__.TreeNode object at 0x00000298CE767C08>
# │                   │   └── <__main__.TreeNode object at 0x00000298CE935E88>
# │                   │       ├── <__main__.TreeNode object at 0x00000298CE767588>
# │                   │       │   ├── <__main__.TreeNode object at 0x00000298CE983F48>
# │                   │       │   └── <__main__.TreeNode object at 0x00000298CE983F08>
# │                   │       └── <__main__.TreeNode object at 0x00000298CE86D208>
# │                   │           ├── <__main__.TreeNode object at 0x00000298CE983E48>
# │                   │           └── <__main__.TreeNode object at 0x00000298CE983208>
# │                   └── <__main__.TreeNode object at 0x00000298CE73C808>
# │                       ├── <__main__.TreeNode object at 0x00000298CE94CA08>
# │                       │   ├── <__main__.TreeNode object at 0x00000298CE99E508>
# │                       │   │   ├── <__main__.TreeNode object at 0x00000298CE983B48>
# │                       │   │   └── <__main__.TreeNode object at 0x00000298CE983788>
# │                       │   └── <__main__.TreeNode object at 0x00000298CE97CBC8>
# │                       │       ├── <__main__.TreeNode object at 0x00000298CE983E08>
# │                       │       └── <__main__.TreeNode object at 0x00000298CE983BC8>
# │                       └── <__main__.TreeNode object at 0x00000298CE9847C8>
# │                           ├── <__main__.TreeNode object at 0x00000298CE99EAC8>
# │                           └── <__main__.TreeNode object at 0x00000298CE84F708>
# └── <__main__.TreeNode object at 0x00000298CE864E48>
#     ├── <__main__.TreeNode object at 0x00000298CE755708>
#     │   ├── <__main__.TreeNode object at 0x00000298CD6E0A48>
#     │   │   ├── <__main__.TreeNode object at 0x00000298CD622B88>
#     │   │   │   ├── <__main__.TreeNode object at 0x00000298CE996BC8>
#     │   │   │   │   ├── <__main__.TreeNode object at 0x00000298CE9354C8>
#     │   │   │   │   └── <__main__.TreeNode object at 0x00000298CE935888>
#     │   │   │   │       ├── <__main__.TreeNode object at 0x00000298CE7CBE88>
#     │   │   │   │       │   ├── <__main__.TreeNode object at 0x00000298CE99EEC8>
#     │   │   │   │       │   └── <__main__.TreeNode object at 0x00000298CE983248>
#     │   │   │   │       └── <__main__.TreeNode object at 0x00000298CE99E1C8>
#     │   │   │   │           ├── <__main__.TreeNode object at 0x00000298CE983148>
#     │   │   │   │           │   ├── <__main__.TreeNode object at 0x00000298CE952608>
#     │   │   │   │           │   └── <__main__.TreeNode object at 0x00000298CE9526C8>
#     │   │   │   │           └── <__main__.TreeNode object at 0x00000298CE98B408>
#     │   │   │   └── <__main__.TreeNode object at 0x00000298CD6E27C8>
#     │   │   └── <__main__.TreeNode object at 0x00000298CE97B648>
#     │   │       ├── <__main__.TreeNode object at 0x00000298CE84F8C8>
#     │   │       │   ├── <__main__.TreeNode object at 0x00000298CE733848>
#     │   │       │   └── <__main__.TreeNode object at 0x00000298CE92E488>
#     │   │       │       ├── <__main__.TreeNode object at 0x00000298CE99C4C8>
#     │   │       │       │   ├── <__main__.TreeNode object at 0x00000298CE7CBD48>
#     │   │       │       │   └── <__main__.TreeNode object at 0x00000298CE94C448>
#     │   │       │       │       ├── <__main__.TreeNode object at 0x00000298CE952888>
#     │   │       │       │       └── <__main__.TreeNode object at 0x00000298CE9523C8>
#     │   │       │       └── <__main__.TreeNode object at 0x00000298CE94C6C8>
#     │   │       │           ├── <__main__.TreeNode object at 0x00000298CE983DC8>
#     │   │       │           │   ├── <__main__.TreeNode object at 0x00000298CE74C3C8>
#     │   │       │           │   └── <__main__.TreeNode object at 0x00000298CE74CBC8>
#     │   │       │           └── <__main__.TreeNode object at 0x00000298CE99EB88>
#     │   │       └── <__main__.TreeNode object at 0x00000298CE733548>
#     │   │           ├── <__main__.TreeNode object at 0x00000298CE84FBC8>
#     │   │           └── <__main__.TreeNode object at 0x00000298CE98BA08>
#     │   │               ├── <__main__.TreeNode object at 0x00000298CE98B9C8>
#     │   │               │   ├── <__main__.TreeNode object at 0x00000298CE996B48>
#     │   │               │   │   ├── <__main__.TreeNode object at 0x00000298CE74CD48>
#     │   │               │   │   └── <__main__.TreeNode object at 0x00000298CE74CB08>
#     │   │               │   └── <__main__.TreeNode object at 0x00000298CE767188>
#     │   │               └── <__main__.TreeNode object at 0x00000298CE935208>
#     │   └── <__main__.TreeNode object at 0x00000298CE8CE148>
#     │       ├── <__main__.TreeNode object at 0x00000298CE7C3208>
#     │       │   ├── <__main__.TreeNode object at 0x00000298CD6A3748>
#     │       │   │   ├── <__main__.TreeNode object at 0x00000298CE996E08>
#     │       │   │   │   ├── <__main__.TreeNode object at 0x00000298CD6DAAC8>
#     │       │   │   │   │   ├── <__main__.TreeNode object at 0x00000298CE952748>
#     │       │   │   │   │   └── <__main__.TreeNode object at 0x00000298CE750C88>
#     │       │   │   │   └── <__main__.TreeNode object at 0x00000298CE952D48>
#     │       │   │   │       ├── <__main__.TreeNode object at 0x00000298CE750E48>
#     │       │   │   │       │   ├── <__main__.TreeNode object at 0x00000298CE932C88>
#     │       │   │   │       │   └── <__main__.TreeNode object at 0x00000298CE932C08>
#     │       │   │   │       └── <__main__.TreeNode object at 0x00000298CE95F408>
#     │       │   │   │           ├── <__main__.TreeNode object at 0x00000298CE932508>
#     │       │   │   │           └── <__main__.TreeNode object at 0x00000298CE932DC8>
#     │       │   │   └── <__main__.TreeNode object at 0x00000298CE99E148>
#     │       │   │       ├── <__main__.TreeNode object at 0x00000298CE7673C8>
#     │       │   │       │   ├── <__main__.TreeNode object at 0x00000298CE996AC8>
#     │       │   │       │   │   ├── <__main__.TreeNode object at 0x00000298CE932B48>
#     │       │   │       │   │   └── <__main__.TreeNode object at 0x00000298CE932488>
#     │       │   │       │   └── <__main__.TreeNode object at 0x00000298CE98B4C8>
#     │       │   │       └── <__main__.TreeNode object at 0x00000298CE7BB908>
#     │       │   │           ├── <__main__.TreeNode object at 0x00000298CE996808>
#     │       │   │           └── <__main__.TreeNode object at 0x00000298CE996248>
#     │       │   └── <__main__.TreeNode object at 0x00000298CE952308>
#     │       │       ├── <__main__.TreeNode object at 0x00000298CE7746C8>
#     │       │       │   ├── <__main__.TreeNode object at 0x00000298CE984608>
#     │       │       │   │   ├── <__main__.TreeNode object at 0x00000298CE935248>
#     │       │       │   │   └── <__main__.TreeNode object at 0x00000298CE99E5C8>
#     │       │       │   └── <__main__.TreeNode object at 0x00000298CE9A2148>
#     │       │       │       ├── <__main__.TreeNode object at 0x00000298CE996288>
#     │       │       │       └── <__main__.TreeNode object at 0x00000298CE767CC8>
#     │       │       └── <__main__.TreeNode object at 0x00000298CE984048>
#     │       │           ├── <__main__.TreeNode object at 0x00000298CE935348>
#     │       │           └── <__main__.TreeNode object at 0x00000298CE84F788>
#     │       └── <__main__.TreeNode object at 0x00000298CD6A3A08>
#     │           ├── <__main__.TreeNode object at 0x00000298CE99CCC8>
#     │           │   ├── <__main__.TreeNode object at 0x00000298CE983C88>
#     │           │   └── <__main__.TreeNode object at 0x00000298CE94C088>
#     │           │       ├── <__main__.TreeNode object at 0x00000298CE74C4C8>
#     │           │       │   ├── <__main__.TreeNode object at 0x00000298CE932448>
#     │           │       │   │   ├── <__main__.TreeNode object at 0x00000298CE7B9D08>
#     │           │       │   │   └── <__main__.TreeNode object at 0x00000298CE7B93C8>
#     │           │       │   └── <__main__.TreeNode object at 0x00000298CE724288>
#     │           │       └── <__main__.TreeNode object at 0x00000298CE932108>
#     │           └── <__main__.TreeNode object at 0x00000298CE9968C8>
#     │               ├── <__main__.TreeNode object at 0x00000298CE99C848>
#     │               │   ├── <__main__.TreeNode object at 0x00000298CE9A2CC8>
#     │               │   └── <__main__.TreeNode object at 0x00000298CE9A2308>
#     │               │       ├── <__main__.TreeNode object at 0x00000298CE932388>
#     │               │       └── <__main__.TreeNode object at 0x00000298CE932088>
#     │               │           ├── <__main__.TreeNode object at 0x00000298CE7B9D48>
#     │               │           └── <__main__.TreeNode object at 0x00000298CE7B9688>
#     │               └── <__main__.TreeNode object at 0x00000298CE7CB508>
#     └── <__main__.TreeNode object at 0x00000298CE755FC8>
#         ├── <__main__.TreeNode object at 0x00000298CE9841C8>
#         └── <__main__.TreeNode object at 0x00000298CE7BB988>
#             ├── <__main__.TreeNode object at 0x00000298CE7C3348>
#             │   ├── <__main__.TreeNode object at 0x00000298CE9837C8>
#             │   │   ├── <__main__.TreeNode object at 0x00000298CE99C748>
#             │   │   │   ├── <__main__.TreeNode object at 0x00000298CE74CD88>
#             │   │   │   │   ├── <__main__.TreeNode object at 0x00000298CE767388>
#             │   │   │   │   └── <__main__.TreeNode object at 0x00000298CE767BC8>
#             │   │   │   └── <__main__.TreeNode object at 0x00000298CE98B988>
#             │   │   └── <__main__.TreeNode object at 0x00000298CE97C5C8>
#             │   └── <__main__.TreeNode object at 0x00000298CE983988>
#             └── <__main__.TreeNode object at 0x00000298CE86D848>
#                 ├── <__main__.TreeNode object at 0x00000298CE983508>
#                 │   ├── <__main__.TreeNode object at 0x00000298CE996A88>
#                 │   └── <__main__.TreeNode object at 0x00000298CE9964C8>
#                 └── <__main__.TreeNode object at 0x00000298CE983108>

# %%
img = load_img(test_path + 'cap.jpg')
print(get_img_class(img, dtree, minimum_purity))
# test correct
# Out:
# cap

# %%
img = load_img(test_path + 'cap2.jpg')
print(get_img_class(img, dtree, minimum_purity))
# test false
# Out:
# tulis

# %%
img = load_img(test_path + 'tulis.jpg')
print(get_img_class(img, dtree, minimum_purity))
# test correct
# Out:
# tulis
