# %%
#### Dependencies

from anytree import Node, NodeMixin, RenderTree
from PIL import Image
from skimage.feature import greycomatrix, greycoprops

import glob
import math
import matplotlib.pyplot as plt
import os
import random

# %%
#### Global variables

model = []
class_names = []
map_8bit_to_3bit = [i // 32 for i in range(256)]

# %%
#### Classes

class MyBaseClass(object):
    foo = 4
    
class TreeNode(MyBaseClass, NodeMixin):
    def __init__(self, subset, purity, glcm_index=0, glcm_median=0, dominant_class='', parent=None, children=None):
        super(TreeNode, self).__init__()
        self.subset = subset
        self.purity = purity
        self.glcm_index = glcm_index
        self.glcm_median = glcm_median
        self.dominant_class = dominant_class
        if(not children == None):
            self.children = children

# %%
#### Functions

def load_img(img_path):
    return Image.open(img_path).convert('L')

def get_img_size(img):
    return img.size

def print_img(img):
    plt.imshow(img, cmap='gray')
    
def get_resized_img(img, dimension):
    return img.resize(dimension)

def get_img_colors(img):
    return list(img.getdata())

def get_3bit_img_colors(img):
    img_colors = get_img_colors(img)
    
    loop_count = 0
    for img_color in img_colors:
        img_colors[loop_count] = map_8bit_to_3bit[img_color]
        
        loop_count += 1
        
    return img_colors

def get_img_matrix(img_colors):
    img_matrix = []
    
    loop_count = 0
    img_square_dimension = int(math.sqrt(len(img_colors)))
    
    for row in range(img_square_dimension):
        temp_row = []
        for col in range(img_square_dimension):
            temp_row.append(img_colors[loop_count])
            
            loop_count += 1
        img_matrix.append(temp_row)
        
    return img_matrix

def get_img_features(img):
    img_3bit_colors = get_3bit_img_colors(img)
    img_matrix = get_img_matrix(img_3bit_colors)
    
    glcm_matrix = greycomatrix(img_matrix, distances=[1], angles=[0], levels=12, symmetric=False, normed=False)
    glcm_components = ['contrast', 'correlation', 'energy', 'homogeneity', 'ASM', 'dissimilarity']
    
    img_features = []
    for glcm_component in glcm_components:
        img_features.append(greycoprops(glcm_matrix, glcm_component)[0][0])
        
    return tuple(img_features)

# Modelling

def init_model():
    global model
    global class_names
    
    model = []
    class_names = []
    
def load_class_names(training_path):
    global class_names
    
    class_names = [class_name for class_name in os.listdir(training_path)]
            
def insert_img_features_into_model(class_name, img_features):
    global model

    row_tuple = (class_name,) + img_features
    model.append(row_tuple)
        
def load_preprocessed_img(img_path, dimension=(128, 128)):
    img = load_img(img_path)
    img = get_resized_img(img, dimension)
    
    return img

def train(training_path, img_type='*.jpg'):
    print('Training...')
    class_names = get_class_names(training_path)
    for class_name in class_names:
        img_paths = glob.glob(training_path + class_name + '/' + img_type)
        
        for img_path in img_paths:            
            img = load_preprocessed_img(img_path)
            img_features = get_img_features(img)

            insert_img_features_into_model(class_name, img_features)
            
    print('--> Done')

def get_splitted_model(sample_rate=0.8):
    sample_model = []
    test_sample_model = []
    
    for row in model:
        random_splitter = random.uniform(0, 1)
        
        if(random_splitter <= sample_rate):
            sample_model.append(row)
        else:
            test_sample_model.append(row)
            
    return sample_model, test_sample_model

def get_subset_purity(subset, minimum_purity=0.8):
    if(len(subset) > 0):        
        total_class = len(class_names)
        total_class_score = len(subset)
        subset_class_scores = [0 for i in range(total_class)]
        
        for row in subset:
            row_class_name = row[0]
            subset_class_scores[class_names.index(row_class_name)] += 1
            
        subset_purity = 0
        for class_index in range(total_class):
            subset_purity += (subset_class_scores[class_index] / total_class_score) ** 2
            
        dominant_class = ''
        if(subset_purity >= minimum_purity):
            maximum_class_scores = max(subset_class_scores)
            dominant_class_index = subset_class_scores.index(maximum_class_scores)
            dominant_class = class_names[dominant_class_index]
            
        return (subset_purity, dominant_class)
    else:
        return (0, '')
    
def get_tree_seed(model, minimum_purity=0.8):
    tree = TreeNode(model, get_subset_purity(model, minimum_purity)[0])
    
    return tree

def get_decision_tree(decision_tree, minimum_purity=0.8, n_branch=2, glcm_length=6):
    if(decision_tree.purity >= minimum_purity or len(decision_tree.subset) == 0):
        return decision_tree
    else:
        subset = decision_tree.subset
        
        class_names = get_class_names_in_model()
        
        branch_future_subset_purities = [[glcm_index, 0] for glcm_index in range(glcm_length)]
        branch_glcm_medians           = [[0 for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_subsets                = [[[] for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_purities               = [[0 for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_dominants              = [['' for glcm_index in range(glcm_length)] for i in range(n_branch)]
        
        for glcm_index in range(glcm_length):
            sorted_subset = sorted(subset, key=lambda x: x[glcm_index + 1])
            sorted_subset_length = len(sorted_subset)
            
            if(sorted_subset_length < n_branch):
                n_branch = sorted_subset_length
                
            row_per_branch = int(sorted_subset_length / n_branch)
            branch_constraint = [row_per_branch * i for i in range(n_branch + 1)]
            branch_constraint[-1] = sorted_subset_length
            
            for branch_index in range(n_branch):
                branch_subsets[branch_index][glcm_index] = sorted_subset[branch_constraint[branch_index]:branch_constraint[branch_index + 1]]
                
                branch_glcm_medians[branch_index][glcm_index] = branch_subsets[branch_index][glcm_index][-1][glcm_index + 1]
                branch_purity_and_dominant = get_subset_purity(branch_subsets[branch_index][glcm_index], minimum_purity)
                branch_purities[branch_index][glcm_index] = branch_purity_and_dominant[0]
                branch_dominants[branch_index][glcm_index] = branch_purity_and_dominant[1]
                
                if(branch_purities[branch_index][glcm_index] >= minimum_purity):
                    branch_future_subset_purities[glcm_index][1] += 1
                    
        sorted_branch_future_subset_purities = sorted(branch_future_subset_purities, key= lambda x: -x[1])
        glcm_index = sorted_branch_future_subset_purities[0][0]
            
        for branch_index in range(n_branch):
            branch_subset = branch_subsets[branch_index][glcm_index]
            branch_purity = branch_purities[branch_index][glcm_index]
            branch_glcm_median = branch_glcm_medians[branch_index][glcm_index]
            branch_dominant = branch_dominants[branch_index][glcm_index]
                
            decision_tree_branch = TreeNode(branch_subset, branch_purity, glcm_index, branch_glcm_median, branch_dominant)
            decision_tree_branch = get_decision_tree(decision_tree_branch, minimum_purity, n_branch)
                
            if(not decision_tree_branch == None):
                decision_tree_branch.parent = decision_tree
            
        return decision_tree
    
def get_random_forest(n_decision_tree, n_decision_tree_branch, sample_rate=0.8, minimum_purity=0.8, epochs=1):
    random_forest = []
    
    for dtree_index in range(n_decision_tree):
        print('Creating Decision Tree ' + str(dtree_index + 1) + ' ...')
        sample_model = []
        test_sample_model = []
        for epoch in range(epochs):
            new_sample_model, new_test_sample_model = get_splitted_model(sample_rate)
            sample_model += new_sample_model
            test_sample_model += new_test_sample_model
            dtree_seed = get_tree_seed(sample_model, minimum_purity)
            dtree = get_decision_tree(dtree_seed, minimum_purity, n_decision_tree_branch)
            test(dtree, test_sample_model, minimum_purity)
        random_forest.append(dtree)
        print('Added Decision Tree to Random Forest!')
        print()
        
    return random_forest   
    
def print_decision_tree(decision_tree):
    print(RenderTree(decision_tree))
    
def print_random_forest(random_forest):
    random_forest_length = len(random_forest)
    for dtree_index in range(random_forest_length):
        print('Decision Tree ' + str(dtree_index + 1))
        print(RenderTree(random_forest[dtree_index]))
        print()
    
def get_img_features_class_with_decision_tree(img_features, decision_tree, minimum_purity=0.8):
    temp_decision_tree = decision_tree
    
    while(temp_decision_tree.purity < minimum_purity and not temp_decision_tree.children == ()):
        childrens = temp_decision_tree.children
        total_childs = len(childrens)
        
        is_glcm_median_not_available = True
        child_index = 0
        for children in childrens:
            glcm_index = children.glcm_index
            glcm_median = children.glcm_median
            
            if(img_features[glcm_index] <= glcm_median):
                is_glcm_median_not_available = False
                break
                
            child_index += 1
                
        if(child_index >= total_childs):
            temp_decision_tree = childrens[-1]
        else:
            temp_decision_tree = childrens[child_index]
            
    img_class_name = temp_decision_tree.dominant_class
    
    return img_class_name
    
def get_img_class_with_decision_tree(img, decision_tree, minimum_purity=0.8):
    img_features = get_img_features(img)
            
    img_class_name = get_img_features_class_with_decision_tree(img_features, decision_tree, minimum_purity)
    
    return img_class_name

def get_img_features_class(img_features, random_forest, minimum_purity=0.8):
    guessed_img_class_name = []
    for dtree in random_forest:
        local_img_class_name = get_img_features_class_with_decision_tree(img_features, dtree, minimum_purity)
        guessed_img_class_name.append(local_img_class_name)
        
    img_class_name = max(set(guessed_img_class_name), key=guessed_img_class_name.count)
    
    return img_class_name

def get_img_class(img, random_forest, minimum_purity=0.8):
    img_features = get_img_features(img)
    
    img_class_name = get_img_features_class(img_features, random_forest, minimum_purity)
    
    return img_class_name
        

def test(decision_tree, test_sample_model, minimum_purity=0.8):
    print('Testing...')
    total_correct_answer = 0
    total_guess = 0
    
    for row in test_sample_model:
        expected_class_name = row[0]
        test_img_features = row[1:]
        test_img_class_name = get_img_features_class_with_decision_tree(test_img_features, decision_tree, minimum_purity)
            
        if(expected_class_name == test_img_class_name):
            total_correct_answer += 1
                
        total_guess += 1
            
    accuracy = (total_correct_answer / total_guess) * 100
    
    print('--> Done, accuracy = ' + str(accuracy) + ' %')
    
    return accuracy
        

def validate(validation_path, random_forest, minimum_purity=0.8, img_type='*.jpg'):
    print('Validating...')
    total_correct_answer = 0
    total_guess = 0
    
    for class_name in class_names:
        img_paths = glob.glob(validation_path + class_name + '/' + img_type)
        for img_path in img_paths:
            img = load_preprocessed_img(img_path)
            img_class_name = get_img_class(img, random_forest, minimum_purity)
            
            if(class_name == img_class_name):
                total_correct_answer += 1
                
            total_guess += 1
            
    print('--> Done')
    
    accuracy = (total_correct_answer / total_guess) * 100
    
    return accuracy

# %%
#### Main

# Defining paths
root_path       = './'
training_path   = root_path + 'training/'
validation_path = root_path + 'validation/'
test_path       = root_path + 'test/'

# Props
img_type = '*.jpg'
n_decision_tree = 9
n_branch_decision_tree = 4
sample_rate = 0.80
minimum_purity = 0.95
epochs = 5

# Init
init_model()
load_class_names(training_path)

train(training_path, img_type)
rforest = get_random_forest(n_decision_tree, n_branch_decision_tree, sample_rate, minimum_purity, epochs)

model_accuracy = validate(validation_path, rforest, minimum_purity, img_type)

print(model_accuracy)
# Out:
# Training...
# --> Done
# Creating Decision Tree 1 ...
# Testing...
# --> Done, accuracy = 89.47368421052632 %
# Testing...
# --> Done, accuracy = 98.09523809523809 %
# Testing...
# --> Done, accuracy = 99.37694704049844 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 2 ...
# Testing...
# --> Done, accuracy = 74.28571428571429 %
# Testing...
# --> Done, accuracy = 98.5781990521327 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 3 ...
# Testing...
# --> Done, accuracy = 88.9908256880734 %
# Testing...
# --> Done, accuracy = 97.95918367346938 %
# Testing...
# --> Done, accuracy = 99.31506849315068 %
# Testing...
# --> Done, accuracy = 99.75186104218362 %
# Testing...
# --> Done, accuracy = 99.80353634577604 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 4 ...
# Testing...
# --> Done, accuracy = 84.25925925925925 %
# Testing...
# --> Done, accuracy = 96.44444444444444 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 98.23399558498896 %
# Testing...
# --> Done, accuracy = 98.75 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 5 ...
# Testing...
# --> Done, accuracy = 84.5528455284553 %
# Testing...
# --> Done, accuracy = 99.07834101382488 %
# Testing...
# --> Done, accuracy = 99.67948717948718 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 6 ...
# Testing...
# --> Done, accuracy = 89.24731182795699 %
# Testing...
# --> Done, accuracy = 97.1563981042654 %
# Testing...
# --> Done, accuracy = 98.7460815047022 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 99.80544747081711 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 7 ...
# Testing...
# --> Done, accuracy = 87.60330578512396 %
# Testing...
# --> Done, accuracy = 95.86776859504133 %
# Testing...
# --> Done, accuracy = 98.26086956521739 %
# Testing...
# --> Done, accuracy = 99.10714285714286 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 8 ...
# Testing...
# --> Done, accuracy = 80.3921568627451 %
# Testing...
# --> Done, accuracy = 98.4536082474227 %
# Testing...
# --> Done, accuracy = 99.6742671009772 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 99.62049335863378 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 9 ...
# Testing...
# --> Done, accuracy = 83.65384615384616 %
# Testing...
# --> Done, accuracy = 96.1352657004831 %
# Testing...
# --> Done, accuracy = 98.70967741935483 %
# Testing...
# --> Done, accuracy = 99.76470588235294 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Validating...
# --> Done
# 90.625

# %%
print_random_forest(rforest)
# Out:
# Decision Tree 1
# <__main__.TreeNode object at 0x000001F4DBD44848>
# ├── <__main__.TreeNode object at 0x000001F4DB726748>
# │   ├── <__main__.TreeNode object at 0x000001F4DBEC11C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC040208>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04B048>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04B288>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04B1C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05BA08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05BB08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05BB88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC05BBC8>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC023E08>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DC023E88>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC04B988>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD6DD88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD6DF08>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBD6D488>
# │   ├── <__main__.TreeNode object at 0x000001F4DB6266C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB4E0788>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB4E2388>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB4E2D48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB4E28C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB4E2588>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC05B408>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC05B788>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC05B808>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC05B848>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBEF2108>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB4E27C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB476EC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB476688>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05BD88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC023548>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0235C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC023788>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC04BC48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC023C08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC0239C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC023AC8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC023248>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBEDB748>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBD5FF48>
# │   ├── <__main__.TreeNode object at 0x000001F4DB651C48>
# │   └── <__main__.TreeNode object at 0x000001F4DB6498C8>
# ├── <__main__.TreeNode object at 0x000001F4DBD99748>
# │   ├── <__main__.TreeNode object at 0x000001F4DBD9FF08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBEDB488>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05BA88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05B7C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05B588>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC05B608>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB669F08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB4767C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBEAF088>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC040E08>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC040BC8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC0308C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC0309C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC030A48>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC03BC88>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DC03BD08>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC030D08>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC023908>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC0238C8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC030608>
# │   │           │   ├── <__main__.TreeNode object at 0x000001F4DC03BFC8>
# │   │           │   └── <__main__.TreeNode object at 0x000001F4DC039088>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC03BD88>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC03BE48>
# │   │           └── <__main__.TreeNode object at 0x000001F4DC03BEC8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBD76188>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBFBC048>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05B048>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05B188>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05B288>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC05BFC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC023F48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC023A08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC023D48>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC023348>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD73608>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBBFD648>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD99EC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD998C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0304C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC030E08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC030648>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC030F08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC03B148>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC03B848>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC030308>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC030408>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC030C08>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC030688>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBEAFFC8>
# │   ├── <__main__.TreeNode object at 0x000001F4DB4E08C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA9C88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD9F788>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD9F248>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC03BF48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC03B7C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC039508>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC039608>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC039688>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC0396C8>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC05D908>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DC05D988>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC030888>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC03B808>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC03B348>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC03B408>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC03B688>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC0303C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC040288>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC05BDC8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC05B1C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC03BA88>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC03BA48>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC03B5C8>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC046208>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DC046288>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC05DF48>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBFB1A08>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC03B888>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC03B208>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC03BE88>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC023848>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC03B908>
# │   └── <__main__.TreeNode object at 0x000001F4DBB720C8>
# │       ├── <__main__.TreeNode object at 0x000001F4DBFC36C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB887388>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC05D488>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC05D6C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC05D088>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DC05D0C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC023188>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB65A908>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC05DD88>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC05D9C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC05DC08>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DC039E88>
# │       │   └── <__main__.TreeNode object at 0x000001F4DC05DE88>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DC0397C8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DC039748>
# │       │       │   ├── <__main__.TreeNode object at 0x000001F4DC053148>
# │       │       │   └── <__main__.TreeNode object at 0x000001F4DC0531C8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DC046E88>
# │       │       └── <__main__.TreeNode object at 0x000001F4DC046F88>
# │       ├── <__main__.TreeNode object at 0x000001F4DBD99E48>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB6267C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB887AC8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC03B8C8>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC053748>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DC0537C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC046C48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC046B48>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DC039988>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB4E2288>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC046908>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC046B08>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC053B88>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DC053C08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC05B108>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DC05D548>
# │       │   └── <__main__.TreeNode object at 0x000001F4DC0237C8>
# │       ├── <__main__.TreeNode object at 0x000001F4DC05B648>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC039E48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC030CC8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC030C48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC030188>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DC030588>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC05D888>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC0300C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC030488>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC027488>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DC027508>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC053F88>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DC053988>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB75ED48>
# │       │   └── <__main__.TreeNode object at 0x000001F4DC05B308>
# │       └── <__main__.TreeNode object at 0x000001F4DB659788>
# ├── <__main__.TreeNode object at 0x000001F4DBC1C988>
# │   ├── <__main__.TreeNode object at 0x000001F4DBD9F948>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBBFDAC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBBFD948>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBBFD088>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC023608>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC039A48>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC039908>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC0398C8>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC039EC8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC053548>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC053AC8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC053288>
# │   │           └── <__main__.TreeNode object at 0x000001F4DC053388>
# │   ├── <__main__.TreeNode object at 0x000001F4DBBFD0C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC040A88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC040948>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC023748>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC03B2C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC027288>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC027388>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC027048>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC03B1C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC03BB88>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC03B488>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD9F648>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD65908>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD65388>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0278C8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC020BC8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC020C48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC027FC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC027CC8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC027D48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC039248>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040C88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040FC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040AC8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC0401C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC0405C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBD9F888>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC05BE88>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC046D88>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC046188>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC034508>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DC034588>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC020788>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC020F08>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC053848>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC053408>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC030248>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC05D848>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC034948>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DC0349C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC03B508>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC020548>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC020FC8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC053488>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC053D48>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC053EC8>
# │   │           │   ├── <__main__.TreeNode object at 0x000001F4DC034D48>
# │   │           │   └── <__main__.TreeNode object at 0x000001F4DC034DC8>
# │   │           └── <__main__.TreeNode object at 0x000001F4DC027BC8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE28748>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBB6D908>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040988>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0403C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040DC8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC040B48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC05DD48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC05D1C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC027A88>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC027AC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC05B488>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04BF88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04BEC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC053A48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC053608>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC055A88>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC055B08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC034E88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC034648>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC039F08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC053C88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05D388>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC055E48>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC055EC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD99448>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC020448>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC03B288>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB519B48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05BE08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC05BD08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0208C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC020388>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC020108>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC00F548>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC00F5C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC053508>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD99208>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC027148>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC027B08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC027B88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC027E48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC034F88>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC053E48>
# │   └── <__main__.TreeNode object at 0x000001F4DBFBCF48>
# └── <__main__.TreeNode object at 0x000001F4DB476A08>
#     ├── <__main__.TreeNode object at 0x000001F4DB64B448>
#     ├── <__main__.TreeNode object at 0x000001F4DB64B8C8>
#     ├── <__main__.TreeNode object at 0x000001F4DBC1C9C8>
#     │   ├── <__main__.TreeNode object at 0x000001F4DC03BE08>
#     │   ├── <__main__.TreeNode object at 0x000001F4DC03BAC8>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DC027D08>
#     │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC020608>
#     │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFF4188>
#     │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFF4208>
#     │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC00FEC8>
#     │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC00FFC8>
#     │   │   │   └── <__main__.TreeNode object at 0x000001F4DC00FC88>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DC0276C8>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DC027608>
#     │   │   └── <__main__.TreeNode object at 0x000001F4DC027708>
#     │   ├── <__main__.TreeNode object at 0x000001F4DC039648>
#     │   └── <__main__.TreeNode object at 0x000001F4DC039408>
#     └── <__main__.TreeNode object at 0x000001F4DC040808>
#         ├── <__main__.TreeNode object at 0x000001F4DC03B608>
#         │   ├── <__main__.TreeNode object at 0x000001F4DC0348C8>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DC055688>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DC055608>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DC055808>
#         │   │   └── <__main__.TreeNode object at 0x000001F4DC055F88>
#         │   ├── <__main__.TreeNode object at 0x000001F4DC05D748>
#         │   ├── <__main__.TreeNode object at 0x000001F4DC023988>
#         │   └── <__main__.TreeNode object at 0x000001F4DC05D3C8>
#         ├── <__main__.TreeNode object at 0x000001F4DBC1C648>
#         ├── <__main__.TreeNode object at 0x000001F4DBB6D188>
#         └── <__main__.TreeNode object at 0x000001F4DBFBC288>
#             ├── <__main__.TreeNode object at 0x000001F4DB6835C8>
#             ├── <__main__.TreeNode object at 0x000001F4DBAC9C88>
#             ├── <__main__.TreeNode object at 0x000001F4DBAC9B48>
#             └── <__main__.TreeNode object at 0x000001F4DC03B308>
#                 ├── <__main__.TreeNode object at 0x000001F4DC00F988>
#                 ├── <__main__.TreeNode object at 0x000001F4DC020C88>
#                 ├── <__main__.TreeNode object at 0x000001F4DC020708>
#                 └── <__main__.TreeNode object at 0x000001F4DC0204C8>
#
# Decision Tree 2
# <__main__.TreeNode object at 0x000001F4DBE37988>
# ├── <__main__.TreeNode object at 0x000001F4DBE4C0C8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE3C3C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB95AEC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC008A88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC008A48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC008488>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC014AC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC014F88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC014F48>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC0143C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC013EC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE26408>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE26AC8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBE26C88>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE32608>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE46908>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC01BB48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC01B408>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC01B488>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC01BAC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC014208>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC05B548>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC05BC48>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC05DDC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC0135C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC004388>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC004788>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC004F48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9F88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9B08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9048>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFE97C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB93C908>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBFE9308>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBFE9D48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBFE9DC8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBFE9E08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC008148>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC013C88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE92C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9948>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE95C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFE9488>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE46408>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC004448>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC014248>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB948748>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE46F48>
# │   └── <__main__.TreeNode object at 0x000001F4DBE3F788>
# ├── <__main__.TreeNode object at 0x000001F4DBE2A988>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE4E548>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC001808>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0147C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC014508>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC014748>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFF188>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFF1C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFF648>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFECA48>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFECB88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFFFF88>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFE91C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE266C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE26288>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBE26188>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC0089C8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC008EC8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC008088>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC001E48>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBFE9208>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBFE9608>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC9C8>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DBFEC848>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DBFEC248>
# │   │       └── <__main__.TreeNode object at 0x000001F4DBE32488>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC001248>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DB93B848>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DB93B308>
# │   │           └── <__main__.TreeNode object at 0x000001F4DB93B4C8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE4CB48>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE493C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE38C08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE32A88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC014788>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC014408>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC014288>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC014D88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFFFC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFF748>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFFF808>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE26988>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9808>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE96C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9F48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC039D08>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC053D08>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC053088>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC020888>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0203C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC034A08>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC01B348>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC013788>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBFFF388>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC013E08>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBFEC608>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC05DBC8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE49648>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE4CAC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC001F48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB93B908>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB93BD88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC488>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC588>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC308>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFF46C8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFF4F08>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC03BDC8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC013B08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE32808>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFF308>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFFC08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFF908>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC2C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFECC48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC448>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFEC808>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC027F88>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DC027548>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC053348>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC039588>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC0399C8>
# │   └── <__main__.TreeNode object at 0x000001F4DBE3FD08>
# │       ├── <__main__.TreeNode object at 0x000001F4DC039D88>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFECF08>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFECFC8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBE38388>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFF47C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFF4648>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC055088>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DC0559C8>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DB93C7C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBE38A48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFF708>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFF7C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFFFEC8>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBFFF8C8>
# │       │   └── <__main__.TreeNode object at 0x000001F4DC034688>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFFF448>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFFFD48>
# │       │       │   ├── <__main__.TreeNode object at 0x000001F4DC046C88>
# │       │       │   └── <__main__.TreeNode object at 0x000001F4DC046588>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFEC7C8>
# │       │       └── <__main__.TreeNode object at 0x000001F4DBFF42C8>
# │       ├── <__main__.TreeNode object at 0x000001F4DBE38548>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFE9688>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFE9248>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFECF88>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC108>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC00FA48>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DC00F788>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBE4ED88>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBFFFAC8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFEC348>
# │       │   └── <__main__.TreeNode object at 0x000001F4DC01BE48>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFF4308>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFF4E88>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFF4B88>
# │       │       └── <__main__.TreeNode object at 0x000001F4DBFF4988>
# │       ├── <__main__.TreeNode object at 0x000001F4DBFFF108>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC03B388>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC023B88>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC0016C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9848>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC00F708>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DC00FB48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC055708>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DC034608>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFFF6C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFF4D48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFF4C48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBFF4688>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBFF4A88>
# │       │   └── <__main__.TreeNode object at 0x000001F4DC01B648>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFF4A08>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFF4248>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFF4088>
# │       │       └── <__main__.TreeNode object at 0x000001F4DBFF4808>
# │       └── <__main__.TreeNode object at 0x000001F4DB930108>
# ├── <__main__.TreeNode object at 0x000001F4DBE20688>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE490C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC004748>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC0048C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC004A88>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC004B88>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC0146C8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC014E48>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC014348>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC053D88>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC055548>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC055308>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC0557C8>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC023708>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC055888>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC00FB08>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC00FE88>
# │   │           └── <__main__.TreeNode object at 0x000001F4DC00F108>
# │   ├── <__main__.TreeNode object at 0x000001F4DC05DB08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC01BFC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC01BDC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9FC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04BB88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04B9C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04B948>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC04BA08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC00F088>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC00F688>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC046A88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE49108>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9548>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040788>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0407C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0408C8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC1C308>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC1C4C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBBFD048>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE32588>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB852D08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04B448>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC04B188>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC1C808>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC1CB08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE4EBC8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBBFD208>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC053308>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBFDB08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBFD788>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBFDBC8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBBFD348>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBE4EE08>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC013A48>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBFF40C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC046608>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC046788>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC046FC8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBFF4748>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBFF4C08>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC046748>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC034788>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC034488>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC034B88>
# │   │       │       ├── <__main__.TreeNode object at 0x000001F4DB4E0A08>
# │   │       │       ├── <__main__.TreeNode object at 0x000001F4DB4E0AC8>
# │   │       │       └── <__main__.TreeNode object at 0x000001F4DB4E0A88>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC001708>
# │   ├── <__main__.TreeNode object at 0x000001F4DC01B248>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB948E88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0345C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC034348>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0346C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC1CA08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC1C888>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC1CF88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC1CBC8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC04BE88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC013DC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFE9348>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040708>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040608>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040C48>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB51BD88>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB51B408>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB65AE48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC020D08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040908>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040108>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040D08>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC040B88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC027A08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040088>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC040648>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0402C8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB620608>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB511448>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB64B848>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC00F848>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC00F808>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC208>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFECD08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFECC88>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFEC6C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBC1CE48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBC1C448>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBC1C5C8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBC1CFC8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB510F88>
# │   └── <__main__.TreeNode object at 0x000001F4DB9484C8>
# └── <__main__.TreeNode object at 0x000001F4DBE49348>
#     ├── <__main__.TreeNode object at 0x000001F4DBE20548>
#     ├── <__main__.TreeNode object at 0x000001F4DC0234C8>
#     ├── <__main__.TreeNode object at 0x000001F4DB95A348>
#     │   ├── <__main__.TreeNode object at 0x000001F4DBFE9148>
#     │   ├── <__main__.TreeNode object at 0x000001F4DBFE9648>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DBC1C588>
#     │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB51B448>
#     │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB51BC48>
#     │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFF45C8>
#     │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFF4EC8>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DB51B7C8>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DB4F7988>
#     │   │   └── <__main__.TreeNode object at 0x000001F4DB4E0048>
#     │   ├── <__main__.TreeNode object at 0x000001F4DBE4E6C8>
#     │   └── <__main__.TreeNode object at 0x000001F4DBE4E0C8>
#     └── <__main__.TreeNode object at 0x000001F4DB4F72C8>
#         ├── <__main__.TreeNode object at 0x000001F4DC008888>
#         │   ├── <__main__.TreeNode object at 0x000001F4DC040F48>
#         │   ├── <__main__.TreeNode object at 0x000001F4DC00F288>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DBD99048>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DBD99788>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DBD99B88>
#         │   │   └── <__main__.TreeNode object at 0x000001F4DBD99C08>
#         │   │       ├── <__main__.TreeNode object at 0x000001F4DB5191C8>
#         │   │       └── <__main__.TreeNode object at 0x000001F4DB519308>
#         │   ├── <__main__.TreeNode object at 0x000001F4DBFECDC8>
#         │   └── <__main__.TreeNode object at 0x000001F4DBFEC548>
#         ├── <__main__.TreeNode object at 0x000001F4DBE4E188>
#         ├── <__main__.TreeNode object at 0x000001F4DBE4E588>
#         └── <__main__.TreeNode object at 0x000001F4DC027C08>
#             ├── <__main__.TreeNode object at 0x000001F4DC053F48>
#             ├── <__main__.TreeNode object at 0x000001F4DB620E48>
#             ├── <__main__.TreeNode object at 0x000001F4DC020948>
#             └── <__main__.TreeNode object at 0x000001F4DB95A488>
#                 ├── <__main__.TreeNode object at 0x000001F4DBC1CCC8>
#                 ├── <__main__.TreeNode object at 0x000001F4DBC1C188>
#                 ├── <__main__.TreeNode object at 0x000001F4DBFF4508>
#                 └── <__main__.TreeNode object at 0x000001F4DBFF4B48>
#
# Decision Tree 3
# <__main__.TreeNode object at 0x000001F4DBAC4348>
# ├── <__main__.TreeNode object at 0x000001F4DBFACA88>
# │   ├── <__main__.TreeNode object at 0x000001F4DB749548>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB93ED48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB747408>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB7474C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB747348>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBD7FEC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBC1AB08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBC1AC08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBC1AC88>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBC1ACC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB93ED08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB93EF08>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB93EB48>
# │   ├── <__main__.TreeNode object at 0x000001F4DB88D508>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB875108>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC07608>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC07908>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC07D08>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC07F08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBE3348>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBE3448>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBE34C8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBBE3508>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB749BC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD5F448>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC073C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBE3888>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBE3988>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBE3A08>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBBE3A48>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBF5C88>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DBBF5D08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB747C48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB476348>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC07948>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBF5FC8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC15088>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBF5D88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBBF5E48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC07348>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB715988>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB669C88>
# │   ├── <__main__.TreeNode object at 0x000001F4DBD241C8>
# │   └── <__main__.TreeNode object at 0x000001F4DB856148>
# ├── <__main__.TreeNode object at 0x000001F4DC014D48>
# │   ├── <__main__.TreeNode object at 0x000001F4DB5A9B48>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB88D588>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB88D208>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB88D448>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC0BB08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC0B808>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC0B988>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC0BBC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBF5C08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBF5788>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBF5888>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBBF5908>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB476F08>
# ...
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC4D08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC45C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC4D48>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBDB4808>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC4388>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBEC4A88>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDB4508>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDB4648>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDB4EC8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBDB4048>
# │   │   │           ├── <__main__.TreeNode object at 0x000001F4DBBC9D48>
# │   │   │           ├── <__main__.TreeNode object at 0x000001F4DBBC9848>
# │   │   │           └── <__main__.TreeNode object at 0x000001F4DBBC9788>
# │   │   └── <__main__.TreeNode object at 0x000001F4DA3D5DC8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBABD448>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBDEF048>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDAA508>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDAA408>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDAAE08>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBDAA648>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDB4A08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDB4988>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDB41C8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBDFA648>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBECA288>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBC4FC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC0748>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC0048>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC0388>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBEC00C8>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB483E08>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DB4834C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDD7688>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBA92D88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBCED2C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBCEDA88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBCED948>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBEC0A08>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBDB6588>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB916308>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB9160C8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBAB5208>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDB4348>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDB40C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDB42C8>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DB4D1348>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBDB4D88>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBDB4BC8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDAAD48>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDAA548>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDAA108>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DA3B1C48>
# │   │       └── <__main__.TreeNode object at 0x000001F4DBDAAE88>
# │   ├── <__main__.TreeNode object at 0x000001F4DBDEFE88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC51C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBDD7C48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC0548>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC0D48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC0F08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB483C08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB483048>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB483408>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB483288>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBDCDDC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB4D1508>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB4D1D88>
# │   └── <__main__.TreeNode object at 0x000001F4DBEC5688>
# │       ├── <__main__.TreeNode object at 0x000001F4DA35F348>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCDEC8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCDD88>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBDDCA08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBDDC148>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBDDC3C8>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCC488>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DBDCCA88>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DA3FA288>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCDB48>
# │       │   └── <__main__.TreeNode object at 0x000001F4DA3D5BC8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DB483748>
# │       │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCCE88>
# │       │       │   └── <__main__.TreeNode object at 0x000001F4DBDCC7C8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBDB4288>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DA3FA9C8>
# │       │       └── <__main__.TreeNode object at 0x000001F4DBDDC6C8>
# │       ├── <__main__.TreeNode object at 0x000001F4DBDB49C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBCED1C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBCEDD88>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB4836C8>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCC608>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DBDCCE08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBDDC488>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBBC9448>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBBC9508>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBDB4A48>
# │       │   └── <__main__.TreeNode object at 0x000001F4DBDB4B48>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DA3FA648>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DA3FA488>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DA3FA0C8>
# │       │       └── <__main__.TreeNode object at 0x000001F4DA3FAC88>
# │       ├── <__main__.TreeNode object at 0x000001F4DBAB5448>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBDFA248>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBDD13C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBDD1F08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DA3B1448>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DA3B1B08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBCEDB48>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBCED208>
# │       │   └── <__main__.TreeNode object at 0x000001F4DA3B1548>
# │       └── <__main__.TreeNode object at 0x000001F4DB4D1908>
# ├── <__main__.TreeNode object at 0x000001F4DBAA4248>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE01348>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBBC4748>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBBC4D48>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DA35FA48>
# │   │   └── <__main__.TreeNode object at 0x000001F4DA35F4C8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DA3FAA48>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DA3FA348>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DA3FAF08>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCC148>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCC108>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCCA08>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DBDCC888>
# │   │       └── <__main__.TreeNode object at 0x000001F4DB4830C8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBDCCC08>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBDCCD08>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBDCC988>
# │   │           └── <__main__.TreeNode object at 0x000001F4DBDADB08>
# │   ├── <__main__.TreeNode object at 0x000001F4DBBC4E88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCDC08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCDF48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3FAAC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDAD188>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDADF48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDADD88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBDAD788>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD110C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC0A48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB483148>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBAB5F88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDDC848>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3FAD88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDAD5C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDAD688>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDADCC8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBDADF08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCD148>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB622088>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB622A08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB622B48>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB622C08>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDCB308>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DBDCBA48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBD11208>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBAB5BC8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBCEDF48>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDDCBC8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDADC08>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDAD808>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCB288>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DBDCBD08>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DA35FE48>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBDDC908>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBDDC1C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCD048>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCD5C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBDCD088>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DBDCD248>
# │   │       └── <__main__.TreeNode object at 0x000001F4DBDCC3C8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBDCD588>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBA82608>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBD11688>
# │   │           └── <__main__.TreeNode object at 0x000001F4DBEC0848>
# │   ├── <__main__.TreeNode object at 0x000001F4DB4FF4C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBBC4688>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCDC88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCD808>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCD288>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBDCDE08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDAD308>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDAD4C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBDCB3C8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBDCBE88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DA3FA548>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBC9208>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBC95C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDCBE08>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3A84C8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DA3A8A88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAB8248>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAB8288>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBAB8308>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEC0148>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBC9588>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBC9A88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAB8D08>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBAB8E08>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBBC9C08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD11D88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3FA908>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3FA848>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3FA2C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DA3FA048>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBEC0DC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBAB8D48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBAB8F88>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBAB8548>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBBC9D88>
# │   └── <__main__.TreeNode object at 0x000001F4DBBC4E08>
# └── <__main__.TreeNode object at 0x000001F4DA3B73C8>
#     ├── <__main__.TreeNode object at 0x000001F4DBDB6B08>
#     ├── <__main__.TreeNode object at 0x000001F4DBDBB208>
#     ├── <__main__.TreeNode object at 0x000001F4DA40BD08>
#     │   ├── <__main__.TreeNode object at 0x000001F4DBBC9E08>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DB6226C8>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DB622B88>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DB6229C8>
#     │   │   └── <__main__.TreeNode object at 0x000001F4DBDD1A88>
#     │   │       ├── <__main__.TreeNode object at 0x000001F4DBDCB948>
#     │   │       ├── <__main__.TreeNode object at 0x000001F4DA3A80C8>
#     │   │       ├── <__main__.TreeNode object at 0x000001F4DA3A8608>
#     │   │       └── <__main__.TreeNode object at 0x000001F4DA3A8388>
#     │   ├── <__main__.TreeNode object at 0x000001F4DBEC4C88>
#     │   ├── <__main__.TreeNode object at 0x000001F4DBEC48C8>
#     │   └── <__main__.TreeNode object at 0x000001F4DBEC4408>
#     └── <__main__.TreeNode object at 0x000001F4DBEC4588>
#         ├── <__main__.TreeNode object at 0x000001F4DBBC9B88>
#         │   ├── <__main__.TreeNode object at 0x000001F4DBDCC188>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DA3A8748>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DA3A8148>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DA3A8BC8>
#         │   │   └── <__main__.TreeNode object at 0x000001F4DA3A8E88>
#         │   ├── <__main__.TreeNode object at 0x000001F4DBAB8C08>
#         │   ├── <__main__.TreeNode object at 0x000001F4DBDCBDC8>
#         │   └── <__main__.TreeNode object at 0x000001F4DA3FA588>
#         ├── <__main__.TreeNode object at 0x000001F4DBAB8788>
#         ├── <__main__.TreeNode object at 0x000001F4DBAB8948>
#         └── <__main__.TreeNode object at 0x000001F4DBAB88C8>
#             ├── <__main__.TreeNode object at 0x000001F4DBDAD388>
#             ├── <__main__.TreeNode object at 0x000001F4DBDDCA88>
#             ├── <__main__.TreeNode object at 0x000001F4DBBC40C8>
#             └── <__main__.TreeNode object at 0x000001F4DA35F388>

# %%
img = load_img(test_path + 'cap.jpg')
print(get_img_class(img, rforest, minimum_purity))
# test correct
# Out:
# cap

# %%
img = load_img(test_path + 'cap2.jpg')
print(get_img_class(img, rforest, minimum_purity))
# test false
# Out:
# tulis

# %%
img = load_img(test_path + 'tulis.jpg')
print(get_img_class(img, rforest, minimum_purity))
# test correct
# Out:
# tulis
