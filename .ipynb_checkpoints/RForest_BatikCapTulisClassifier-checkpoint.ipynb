# %%
#### Dependencies

from anytree import Node, NodeMixin, RenderTree
from PIL import Image
from skimage.feature import greycomatrix, greycoprops

import glob
import math
import matplotlib.pyplot as plt
import os
import random

# %%
#### Global variables

model = []
class_names = []
map_8bit_to_3bit = [i // 32 for i in range(256)]

# %%
#### Classes

class MyBaseClass(object):
    foo = 4
    
class TreeNode(MyBaseClass, NodeMixin):
    def __init__(self, subset, purity, glcm_index=0, glcm_median=0, dominant_class='', parent=None, children=None):
        super(TreeNode, self).__init__()
        self.subset = subset
        self.purity = purity
        self.glcm_index = glcm_index
        self.glcm_median = glcm_median
        self.dominant_class = dominant_class
        if(not children == None):
            self.children = children

# %%
#### Functions

def load_img(img_path):
    return Image.open(img_path).convert('L')

def get_img_size(img):
    return img.size

def print_img(img):
    plt.imshow(img, cmap='gray')
    
def get_resized_img(img, dimension):
    return img.resize(dimension)

def get_img_colors(img):
    return list(img.getdata())

def get_3bit_img_colors(img):
    img_colors = get_img_colors(img)
    
    loop_count = 0
    for img_color in img_colors:
        img_colors[loop_count] = map_8bit_to_3bit[img_color]
        
        loop_count += 1
        
    return img_colors

def get_img_matrix(img_colors):
    img_matrix = []
    
    loop_count = 0
    img_square_dimension = int(math.sqrt(len(img_colors)))
    
    for row in range(img_square_dimension):
        temp_row = []
        for col in range(img_square_dimension):
            temp_row.append(img_colors[loop_count])
            
            loop_count += 1
        img_matrix.append(temp_row)
        
    return img_matrix

def get_img_features(img):
    img_3bit_colors = get_3bit_img_colors(img)
    img_matrix = get_img_matrix(img_3bit_colors)
    
    glcm_matrix = greycomatrix(img_matrix, distances=[1], angles=[0], levels=12, symmetric=False, normed=False)
    glcm_components = ['contrast', 'correlation', 'energy', 'homogeneity', 'ASM', 'dissimilarity']
    
    img_features = []
    for glcm_component in glcm_components:
        img_features.append(greycoprops(glcm_matrix, glcm_component)[0][0])
        
    return tuple(img_features)

# Modelling

def init_model():
    global model
    global class_names
    
    model = []
    class_names = []
    
def load_class_names(training_path):
    global class_names
    
    class_names = [class_name for class_name in os.listdir(training_path)]
            
def insert_img_features_into_model(class_name, img_features):
    global model

    row_tuple = (class_name,) + img_features
    model.append(row_tuple)
        
def load_preprocessed_img(img_path, dimension=(128, 128)):
    img = load_img(img_path)
    img = get_resized_img(img, dimension)
    
    return img

def train(training_path, img_type='*.jpg'):
    print('Training...')
    class_names = get_class_names(training_path)
    for class_name in class_names:
        img_paths = glob.glob(training_path + class_name + '/' + img_type)
        
        for img_path in img_paths:            
            img = load_preprocessed_img(img_path)
            img_features = get_img_features(img)

            insert_img_features_into_model(class_name, img_features)
            
    print('--> Done')

def get_splitted_model(sample_rate=0.8):
    sample_model = []
    test_sample_model = []
    
    for row in model:
        random_splitter = random.uniform(0, 1)
        
        if(random_splitter <= sample_rate):
            sample_model.append(row)
        else:
            test_sample_model.append(row)
            
    return sample_model, test_sample_model

def get_subset_purity(subset, minimum_purity=0.8):
    if(len(subset) > 0):        
        total_class = len(class_names)
        total_class_score = len(subset)
        subset_class_scores = [0 for i in range(total_class)]
        
        for row in subset:
            row_class_name = row[0]
            subset_class_scores[class_names.index(row_class_name)] += 1
            
        subset_purity = 0
        for class_index in range(total_class):
            subset_purity += (subset_class_scores[class_index] / total_class_score) ** 2
            
        dominant_class = ''
        if(subset_purity >= minimum_purity):
            maximum_class_scores = max(subset_class_scores)
            dominant_class_index = subset_class_scores.index(maximum_class_scores)
            dominant_class = class_names[dominant_class_index]
            
        return (subset_purity, dominant_class)
    else:
        return (0, '')
    
def get_tree_seed(subset, minimum_purity=0.8):
    tree = TreeNode(subset, get_subset_purity(subset, minimum_purity)[0])
    
    return tree

def get_decision_tree(decision_tree, minimum_purity=0.8, n_branch=2, glcm_length=6):
    if(decision_tree.purity >= minimum_purity or len(decision_tree.subset) == 0):
        return decision_tree
    else:
        subset = decision_tree.subset
        
        class_names = get_class_names_in_model()
        
        branch_future_subset_purities = [[glcm_index, 0] for glcm_index in range(glcm_length)]
        branch_glcm_medians           = [[0 for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_subsets                = [[[] for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_purities               = [[0 for glcm_index in range(glcm_length)] for i in range(n_branch)]
        branch_dominants              = [['' for glcm_index in range(glcm_length)] for i in range(n_branch)]
        
        for glcm_index in range(glcm_length):
            sorted_subset = sorted(subset, key=lambda x: x[glcm_index + 1])
            sorted_subset_length = len(sorted_subset)
            
            if(sorted_subset_length < n_branch):
                n_branch = sorted_subset_length
                
            row_per_branch = int(sorted_subset_length / n_branch)
            branch_constraint = [row_per_branch * i for i in range(n_branch + 1)]
            branch_constraint[-1] = sorted_subset_length
            
            for branch_index in range(n_branch):
                branch_subsets[branch_index][glcm_index] = sorted_subset[branch_constraint[branch_index]:branch_constraint[branch_index + 1]]
                
                branch_glcm_medians[branch_index][glcm_index] = branch_subsets[branch_index][glcm_index][-1][glcm_index + 1]
                branch_purity_and_dominant = get_subset_purity(branch_subsets[branch_index][glcm_index], minimum_purity)
                branch_purities[branch_index][glcm_index] = branch_purity_and_dominant[0]
                branch_dominants[branch_index][glcm_index] = branch_purity_and_dominant[1]
                
                if(branch_purities[branch_index][glcm_index] >= minimum_purity):
                    branch_future_subset_purities[glcm_index][1] += 1
                    
        sorted_branch_future_subset_purities = sorted(branch_future_subset_purities, key= lambda x: -x[1])
        glcm_index = sorted_branch_future_subset_purities[0][0]
            
        for branch_index in range(n_branch):
            branch_subset = branch_subsets[branch_index][glcm_index]
            branch_purity = branch_purities[branch_index][glcm_index]
            branch_glcm_median = branch_glcm_medians[branch_index][glcm_index]
            branch_dominant = branch_dominants[branch_index][glcm_index]
                
            decision_tree_branch = TreeNode(branch_subset, branch_purity, glcm_index, branch_glcm_median, branch_dominant)
            decision_tree_branch = get_decision_tree(decision_tree_branch, minimum_purity, n_branch)
                
            if(not decision_tree_branch == None):
                decision_tree_branch.parent = decision_tree
            
        return decision_tree
    
def get_random_forest(n_decision_tree, n_decision_tree_branch, sample_rate=0.8, minimum_purity=0.8, epochs=1):
    random_forest = []
    
    for dtree_index in range(n_decision_tree):
        print('Creating Decision Tree ' + str(dtree_index + 1) + ' ...')
        sample_model = []
        test_sample_model = []
        for epoch in range(epochs):
            new_sample_model, new_test_sample_model = get_splitted_model(sample_rate)
            sample_model += new_sample_model
            test_sample_model += new_test_sample_model
            dtree_seed = get_tree_seed(sample_model, minimum_purity)
            dtree = get_decision_tree(dtree_seed, minimum_purity, n_decision_tree_branch)
            test(dtree, test_sample_model, minimum_purity)
        random_forest.append(dtree)
        print('Added Decision Tree to Random Forest!')
        print()
        
    return random_forest   
    
def print_decision_tree(decision_tree):
    print(RenderTree(decision_tree))
    
def print_random_forest(random_forest):
    random_forest_length = len(random_forest)
    for dtree_index in range(random_forest_length):
        print('Decision Tree ' + str(dtree_index + 1))
        print(RenderTree(random_forest[dtree_index]))
        print()
    
def get_img_features_class_with_decision_tree(img_features, decision_tree, minimum_purity=0.8):
    temp_decision_tree = decision_tree
    
    while(temp_decision_tree.purity < minimum_purity and not temp_decision_tree.children == ()):
        childrens = temp_decision_tree.children
        total_childs = len(childrens)
        
        is_glcm_median_not_available = True
        child_index = 0
        for children in childrens:
            glcm_index = children.glcm_index
            glcm_median = children.glcm_median
            
            if(img_features[glcm_index] <= glcm_median):
                is_glcm_median_not_available = False
                break
                
            child_index += 1
                
        if(child_index >= total_childs):
            temp_decision_tree = childrens[-1]
        else:
            temp_decision_tree = childrens[child_index]
            
    img_class_name = temp_decision_tree.dominant_class
    
    return img_class_name
    
def get_img_class_with_decision_tree(img, decision_tree, minimum_purity=0.8):
    img_features = get_img_features(img)
            
    img_class_name = get_img_features_class_with_decision_tree(img_features, decision_tree, minimum_purity)
    
    return img_class_name

def get_img_features_class(img_features, random_forest, minimum_purity=0.8):
    guessed_img_class_name = []
    for dtree in random_forest:
        local_img_class_name = get_img_features_class_with_decision_tree(img_features, dtree, minimum_purity)
        guessed_img_class_name.append(local_img_class_name)
        
    img_class_name = max(set(guessed_img_class_name), key=guessed_img_class_name.count)
    
    return img_class_name

def get_img_class(img, random_forest, minimum_purity=0.8):
    img_features = get_img_features(img)
    
    img_class_name = get_img_features_class(img_features, random_forest, minimum_purity)
    
    return img_class_name
        

def test(decision_tree, test_sample_model, minimum_purity=0.8):
    print('Testing...')
    total_correct_answer = 0
    total_guess = 0
    
    for row in test_sample_model:
        expected_img_class_name = row[0]
        test_img_features = row[1:]
        test_img_class_name = get_img_features_class_with_decision_tree(test_img_features, decision_tree, minimum_purity)
            
        if(expected_img_class_name == test_img_class_name):
            total_correct_answer += 1
                
        total_guess += 1
            
    accuracy = (total_correct_answer / total_guess) * 100
    
    print('--> Done, accuracy = ' + str(accuracy) + ' %')
    
    return accuracy
        

def validate(validation_path, random_forest, minimum_purity=0.8, img_type='*.jpg'):
    print('Validating...')
    total_correct_answer = 0
    total_guess = 0
    
    for class_name in class_names:
        img_paths = glob.glob(validation_path + class_name + '/' + img_type)
        for img_path in img_paths:
            img = load_preprocessed_img(img_path)
            img_class_name = get_img_class(img, random_forest, minimum_purity)
            
            if(class_name == img_class_name):
                total_correct_answer += 1
                
            total_guess += 1
            
    print('--> Done')
    
    accuracy = (total_correct_answer / total_guess) * 100
    
    return accuracy

# %%
#### Main

# Defining paths
root_path       = './'
training_path   = root_path + 'training/'
validation_path = root_path + 'validation/'
test_path       = root_path + 'test/'

# Props
img_type = '*.jpg'
n_decision_tree = 9
n_branch_decision_tree = 4
sample_rate = 0.80
minimum_purity = 0.95
epochs = 5

# Init
init_model()
load_class_names(training_path)

train(training_path, img_type)
rforest = get_random_forest(n_decision_tree, n_branch_decision_tree, sample_rate, minimum_purity, epochs)

model_accuracy = validate(validation_path, rforest, minimum_purity, img_type)

print(model_accuracy)
# Out:
# Training...
# --> Done
# Creating Decision Tree 1 ...
# Testing...
# --> Done, accuracy = 89.7196261682243 %
# Testing...
# --> Done, accuracy = 97.75784753363229 %
# Testing...
# --> Done, accuracy = 98.13084112149532 %
# Testing...
# --> Done, accuracy = 99.54022988505747 %
# Testing...
# --> Done, accuracy = 99.63302752293578 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 2 ...
# Testing...
# --> Done, accuracy = 88.67924528301887 %
# Testing...
# --> Done, accuracy = 97.66355140186917 %
# Testing...
# --> Done, accuracy = 99.68354430379746 %
# Testing...
# --> Done, accuracy = 99.76744186046511 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 3 ...
# Testing...
# --> Done, accuracy = 90.47619047619048 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 99.33993399339934 %
# Testing...
# --> Done, accuracy = 99.26829268292683 %
# Testing...
# --> Done, accuracy = 99.62825278810409 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 4 ...
# Testing...
# --> Done, accuracy = 85.3211009174312 %
# Testing...
# --> Done, accuracy = 94.52054794520548 %
# Testing...
# --> Done, accuracy = 99.6923076923077 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 5 ...
# Testing...
# --> Done, accuracy = 87.5 %
# Testing...
# --> Done, accuracy = 97.33333333333334 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 6 ...
# Testing...
# --> Done, accuracy = 85.18518518518519 %
# Testing...
# --> Done, accuracy = 98.04878048780488 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 7 ...
# Testing...
# --> Done, accuracy = 86.86868686868688 %
# Testing...
# --> Done, accuracy = 97.23502304147466 %
# Testing...
# --> Done, accuracy = 98.75389408099689 %
# Testing...
# --> Done, accuracy = 99.52380952380952 %
# Testing...
# --> Done, accuracy = 99.62616822429906 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 8 ...
# Testing...
# --> Done, accuracy = 87.5 %
# Testing...
# --> Done, accuracy = 97.16981132075472 %
# Testing...
# --> Done, accuracy = 98.08917197452229 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Added Decision Tree to Random Forest!
#
# Creating Decision Tree 9 ...
# Testing...
# --> Done, accuracy = 88.42975206611571 %
# Testing...
# --> Done, accuracy = 95.63318777292577 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 100.0 %
# Testing...
# --> Done, accuracy = 99.31153184165233 %
# Added Decision Tree to Random Forest!
#
# Validating...
# --> Done
# 89.0625

# %%
print_random_forest(rforest)
# Out:
# Decision Tree 1
# <__main__.TreeNode object at 0x000001F4DBA71788>
# ├── <__main__.TreeNode object at 0x000001F4DB97B908>
# │   ├── <__main__.TreeNode object at 0x000001F4DA3B8E48>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB979388>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8A97C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8A99C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8A9F88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3B0708>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC96B48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC96588>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC96908>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DA3B0048>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD76408>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBB0F788>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBB8A608>
# │   ├── <__main__.TreeNode object at 0x000001F4DC098648>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB914A48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD73648>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD73688>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD73148>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBD73A08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB905188>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB905688>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB905B88>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DB9050C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBB993C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF1F348>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF1F688>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBB6D608>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA8D88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA8408>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD2C288>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBD2C9C8>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBE327C8>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DBE328C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBBE3C08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB5DEF08>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB619BC8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBC15AC8>
# │   └── <__main__.TreeNode object at 0x000001F4DBF55388>
# ├── <__main__.TreeNode object at 0x000001F4DB709148>
# │   ├── <__main__.TreeNode object at 0x000001F4DBEF8C48>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBFC6348>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB88D5C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBB99448>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8A9448>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB8A9188>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBA85B08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBDFC888>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBDFC988>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBFEC288>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC061488>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC061088>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC061B88>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC061F88>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBD1CBC8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC116408>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DA3B7148>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBE53088>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DA3B7208>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DA400088>
# │   │       └── <__main__.TreeNode object at 0x000001F4DB965608>
# │   ├── <__main__.TreeNode object at 0x000001F4DB96AE88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB914C88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB887348>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8A9048>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8A9AC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFD7D48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB8A9608>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBC79F48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF3E048>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF3E488>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBCE99C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBCE9F48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBCE9348>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFAC308>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFAC808>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB8BD088>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB674388>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD6D948>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD6DDC8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFACD48>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFACF48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE90D08>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBE90908>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB4A7F08>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBF18CC8>
# │   ├── <__main__.TreeNode object at 0x000001F4DC061508>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBB8A9C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB5D8D88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB5D8DC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB5D87C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB5D83C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBB9FE48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD14288>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD143C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDB6EC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFACA08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFAC348>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB46F248>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB46F808>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBE261C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBE174C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB6709C8>
# │   └── <__main__.TreeNode object at 0x000001F4DBD1C848>
# │       ├── <__main__.TreeNode object at 0x000001F4DBCE9688>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFAC908>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFAC6C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFACD08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBD6DA48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBD6DF48>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB662188>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DB6626C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DA404248>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DB8FDC48>
# │       │   └── <__main__.TreeNode object at 0x000001F4DBBBAE88>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBD6DC08>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DB871188>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DB46FE08>
# │       │       └── <__main__.TreeNode object at 0x000001F4DBD2C7C8>
# │       ├── <__main__.TreeNode object at 0x000001F4DBF03408>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBE53048>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBF1D608>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBBBAE48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBBBAF48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBD2C988>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBD2C1C8>
# │       │   │       ├── <__main__.TreeNode object at 0x000001F4DB5B9688>
# │       │   │       └── <__main__.TreeNode object at 0x000001F4DB5B9E08>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB8FD248>
# │       │   └── <__main__.TreeNode object at 0x000001F4DB8FDFC8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBD6D788>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBD6D748>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DB856488>
# │       │       └── <__main__.TreeNode object at 0x000001F4DB905EC8>
# │       ├── <__main__.TreeNode object at 0x000001F4DBE17088>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB46FA08>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB46F708>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBE90B48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBEFE3C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBD1C688>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DB4A7E88>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBEFEE48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB7E9A48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB7E9D48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB7E95C8>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DB7E9C88>
# │       │   └── <__main__.TreeNode object at 0x000001F4DB7E9048>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DB662F08>
# │       │       │   ├── <__main__.TreeNode object at 0x000001F4DBE3C248>
# │       │       │   └── <__main__.TreeNode object at 0x000001F4DBAC44C8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBE3C388>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBE3C4C8>
# │       │       └── <__main__.TreeNode object at 0x000001F4DBE3CE08>
# │       └── <__main__.TreeNode object at 0x000001F4DBF03248>
# ├── <__main__.TreeNode object at 0x000001F4DBBE3048>
# │   ├── <__main__.TreeNode object at 0x000001F4DBDF0988>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBB8A308>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB914F08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB914748>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB914948>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB8565C8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB856748>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBD2CA08>
# │   │       └── <__main__.TreeNode object at 0x000001F4DBD2CCC8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DB749C88>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBE3C208>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBE3C288>
# │   │           │   ├── <__main__.TreeNode object at 0x000001F4DBD383C8>
# │   │           │   └── <__main__.TreeNode object at 0x000001F4DBD38808>
# │   │           └── <__main__.TreeNode object at 0x000001F4DA3AC208>
# │   ├── <__main__.TreeNode object at 0x000001F4DBD1EE08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBEAF548>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB4A79C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB7E9E08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB46FD48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB749848>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB662588>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB662848>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE90488>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC08B7C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB46F188>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBCA45C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB905A08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB5B9348>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB5B9908>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBD8AC8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBBD81C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD38508>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBD388C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFECA08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC988>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB462B88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBBAB08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBBADC8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC01B488>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC01B148>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB5B9A08>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB856308>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBD38A08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DA4043C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DA404F08>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBD2C848>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBFAC9C8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB674188>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBAB8C88>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DB871C08>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC01BAC8>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DC01BE08>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBBD8348>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DBBD8C48>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB662508>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB905148>
# │   │       └── <__main__.TreeNode object at 0x000001F4DB4A7B48>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBD38848>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBD38488>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBD38308>
# │   │           └── <__main__.TreeNode object at 0x000001F4DBD38E48>
# │   │               ├── <__main__.TreeNode object at 0x000001F4DC0EEEC8>
# │   │               ├── <__main__.TreeNode object at 0x000001F4DC0EE6C8>
# │   │               ├── <__main__.TreeNode object at 0x000001F4DC0EE608>
# │   │               └── <__main__.TreeNode object at 0x000001F4DC0EEA88>
# │   ├── <__main__.TreeNode object at 0x000001F4DBB8A2C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD2C4C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFAC1C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFAC4C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFAC048>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFACB48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC01BC48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC01BA88>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB602188>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DB602E48>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBEDD208>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFAC7C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFAC2C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD38B88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD38188>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD38B48>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBD38CC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBD8188>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB602BC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBD38A48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBD38DC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBD389C8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBD38F88>
# │   │   │           ├── <__main__.TreeNode object at 0x000001F4DB75D088>
# │   │   │           ├── <__main__.TreeNode object at 0x000001F4DB75D0C8>
# │   │   │           └── <__main__.TreeNode object at 0x000001F4DB75DEC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB96C508>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8FD8C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB46F608>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBBD8108>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB75D808>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB75DE88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC01B2C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0EE088>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB871848>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB887C48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB6627C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBD8308>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBD8888>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBBD8E08>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBBD8A88>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC01B5C8>
# │   └── <__main__.TreeNode object at 0x000001F4DBE0B0C8>
# └── <__main__.TreeNode object at 0x000001F4DBD76D08>
#     ├── <__main__.TreeNode object at 0x000001F4DBD116C8>
#     ├── <__main__.TreeNode object at 0x000001F4DBD11888>
#     ├── <__main__.TreeNode object at 0x000001F4DBD11DC8>
#     │   ├── <__main__.TreeNode object at 0x000001F4DC01B348>
#     │   ├── <__main__.TreeNode object at 0x000001F4DC01B988>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DB662688>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DB662B08>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DBE903C8>
#     │   │   └── <__main__.TreeNode object at 0x000001F4DBE90B08>
#     │   ├── <__main__.TreeNode object at 0x000001F4DA3AD748>
#     │   └── <__main__.TreeNode object at 0x000001F4DB8BD048>
#     └── <__main__.TreeNode object at 0x000001F4DBDD5E48>
#         ├── <__main__.TreeNode object at 0x000001F4DA400588>
#         │   ├── <__main__.TreeNode object at 0x000001F4DBE3C488>
#         │   ├── <__main__.TreeNode object at 0x000001F4DBE3C048>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DBD38948>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DBD38C88>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DB95A548>
#         │   │   └── <__main__.TreeNode object at 0x000001F4DB95A308>
#         │   ├── <__main__.TreeNode object at 0x000001F4DBEB1848>
#         │   └── <__main__.TreeNode object at 0x000001F4DBD387C8>
#         ├── <__main__.TreeNode object at 0x000001F4DA3ACE48>
#         ├── <__main__.TreeNode object at 0x000001F4DC05AA48>
#         └── <__main__.TreeNode object at 0x000001F4DA3ACF88>
#             ├── <__main__.TreeNode object at 0x000001F4DBE4CA88>
#             ├── <__main__.TreeNode object at 0x000001F4DBE4C188>
#             ├── <__main__.TreeNode object at 0x000001F4DBE4C048>
#             └── <__main__.TreeNode object at 0x000001F4DBE4C9C8>
#                 ├── <__main__.TreeNode object at 0x000001F4DB95A088>
#                 ├── <__main__.TreeNode object at 0x000001F4DB95A1C8>
#                 ├── <__main__.TreeNode object at 0x000001F4DB95A508>
#                 └── <__main__.TreeNode object at 0x000001F4DB95A488>
#
# Decision Tree 2
# <__main__.TreeNode object at 0x000001F4DBD7FC88>
# ├── <__main__.TreeNode object at 0x000001F4DB6DDD08>
# │   ├── <__main__.TreeNode object at 0x000001F4DC13D1C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC12BC88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC123748>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC123EC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC123808>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC123848>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC155D88>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC155E88>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC155F08>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC155F48>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC140E08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC14A9C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB6B6348>
# │   ├── <__main__.TreeNode object at 0x000001F4DBC9C888>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC15A688>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC153788>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC153C48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC153FC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC159588>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC159688>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC159708>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15B948>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC15B9C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC159D48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC123DC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC153408>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC159608>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC1592C8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC159308>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A62C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6C7648>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6C7CC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC123A08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC1230C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC123248>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC123308>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC12B808>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC12BCC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC140E48>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBC689C8>
# │   ├── <__main__.TreeNode object at 0x000001F4DC140DC8>
# │   └── <__main__.TreeNode object at 0x000001F4DC140748>
# ├── <__main__.TreeNode object at 0x000001F4DB626B48>
# │   ├── <__main__.TreeNode object at 0x000001F4DC13D4C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC13F9C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15AF08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15A7C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15B7C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15B588>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15B188>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC157BC8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC157C48>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC15BFC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC153048>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC159448>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC12BA88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC12BE88>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC12B588>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC15AC88>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC15A348>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC159A48>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC1590C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC159148>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC14E388>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DC14E408>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC15B408>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC13F548>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC13F8C8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DB6B6108>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DB6B6488>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC15A3C8>
# │   │           └── <__main__.TreeNode object at 0x000001F4DC15A508>
# │   ├── <__main__.TreeNode object at 0x000001F4DB7E9108>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC13F0C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0462C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC14A548>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC14A0C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC14A808>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC123388>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB6C77C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB6C7848>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DB6C7D08>
# │   │   │           ├── <__main__.TreeNode object at 0x000001F4DB6C7108>
# │   │   │           ├── <__main__.TreeNode object at 0x000001F4DB6C7F08>
# │   │   │           └── <__main__.TreeNode object at 0x000001F4DB6C7E48>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC13D988>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC153108>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC123448>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC123F88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC123048>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC123E08>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC132B08>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC123888>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC157A48>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC15B248>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC15BE48>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC15BEC8>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC15BA48>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC15AFC8>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC15AE48>
# │   ├── <__main__.TreeNode object at 0x000001F4DC140108>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC13FB48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15B6C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15BC48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15BD88>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC15BC88>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB6A6908>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB6A6308>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB6A6288>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DB6A6348>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC12B148>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC12D748>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC12DB08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6DDDC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6DD208>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6DD708>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB6DD948>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A6E48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB6A66C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB6DD6C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB6DD508>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB6DDE88>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DB6DDAC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC123D48>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC157588>
# │   └── <__main__.TreeNode object at 0x000001F4DC13DFC8>
# │       ├── <__main__.TreeNode object at 0x000001F4DC1577C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC159EC8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC159B48>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB6A69C8>
# │       │   └── <__main__.TreeNode object at 0x000001F4DB6A6988>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DB6A7F88>
# │       │       │   ├── <__main__.TreeNode object at 0x000001F4DBC9B688>
# │       │       │   └── <__main__.TreeNode object at 0x000001F4DBC9BBC8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBC61288>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBC61C08>
# │       │       └── <__main__.TreeNode object at 0x000001F4DBC619C8>
# │       ├── <__main__.TreeNode object at 0x000001F4DBD1C308>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC159048>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC159408>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC159948>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A7788>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A71C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A7508>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC7AB48>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC7ADC8>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBC9C508>
# │       │   └── <__main__.TreeNode object at 0x000001F4DB6A6AC8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DC157508>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DC157B48>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DC157148>
# │       │       └── <__main__.TreeNode object at 0x000001F4DC1578C8>
# │       ├── <__main__.TreeNode object at 0x000001F4DC12D6C8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB6DD3C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBC9CA08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBC9C908>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC15BF88>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBC73DC8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBC9C088>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DC159A88>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73848>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73F08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73888>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBC73708>
# │       │   └── <__main__.TreeNode object at 0x000001F4DC15A5C8>
# │       └── <__main__.TreeNode object at 0x000001F4DBC9C5C8>
# ├── <__main__.TreeNode object at 0x000001F4DC13D348>
# │   ├── <__main__.TreeNode object at 0x000001F4DC159E88>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC13FA08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC13FBC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC1557C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC155F88>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC157408>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC157D88>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC157DC8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBC7AEC8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBC7A808>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBC7AD88>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBC863C8>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DBC862C8>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC001A08>
# │   │       └── <__main__.TreeNode object at 0x000001F4DBC9BA48>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBC73988>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBC73CC8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBC73148>
# │   │           └── <__main__.TreeNode object at 0x000001F4DC1575C8>
# │   ├── <__main__.TreeNode object at 0x000001F4DC123D08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC15B1C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC15B8C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A6388>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A6488>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC157CC8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC68AC8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC683C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC758C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC75F88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC754C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73648>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC73408>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB6C7F88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC159B08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC159A08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A7F48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6DD788>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB4E2808>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB4E2C48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC7A4C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC7A788>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC7AF08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A76C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15BC08>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB4E2648>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB4E28C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB981F08>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC159F48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DA3B7B88>
# │   │   └── <__main__.TreeNode object at 0x000001F4DC15AB08>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBC7A2C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC155C08>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DB6A7988>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DB6A7408>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DB6A7308>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB981F48>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB981488>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DB6A7888>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DA3ACA48>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBC68248>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DC046F08>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DC046708>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DC157288>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC159388>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DB6C7D88>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DB6C7948>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DB6C7B08>
# │   │           └── <__main__.TreeNode object at 0x000001F4DB6C7348>
# │   ├── <__main__.TreeNode object at 0x000001F4DC13F488>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBC61F48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A7248>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A7D08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6A75C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB6A7048>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB4E26C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB4E2188>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC12B188>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC12BEC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBC75548>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15B648>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC15B048>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC682C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC68A48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC68A08>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE3FC08>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBE3F5C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB71C688>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6C7408>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73D48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73808>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC12B2C8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC12B0C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB6DDB08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DC001FC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6DD108>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6DDFC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73748>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC73EC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DC155A08>
# │   │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC0FACC8>
# │   │   │       │   └── <__main__.TreeNode object at 0x000001F4DC0FA4C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB707708>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBE3FBC8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DC0460C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBC61548>
# │   └── <__main__.TreeNode object at 0x000001F4DC1328C8>
# └── <__main__.TreeNode object at 0x000001F4DC15AAC8>
#     ├── <__main__.TreeNode object at 0x000001F4DBC9C188>
#     ├── <__main__.TreeNode object at 0x000001F4DBC9C248>
#     ├── <__main__.TreeNode object at 0x000001F4DC153B88>
#     │   ├── <__main__.TreeNode object at 0x000001F4DC046EC8>
#     │   ├── <__main__.TreeNode object at 0x000001F4DB6C70C8>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DB4E2208>
#     │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73308>
#     │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73B88>
#     │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73608>
#     │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFF4988>
#     │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBFF4388>
#     │   │   │   └── <__main__.TreeNode object at 0x000001F4DB6FF748>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DBC735C8>
#     │   │   ├── <__main__.TreeNode object at 0x000001F4DBC73048>
#     │   │   └── <__main__.TreeNode object at 0x000001F4DBC73AC8>
#     │   ├── <__main__.TreeNode object at 0x000001F4DC14A4C8>
#     │   └── <__main__.TreeNode object at 0x000001F4DC14A088>
#     └── <__main__.TreeNode object at 0x000001F4DB707888>
#         ├── <__main__.TreeNode object at 0x000001F4DC159508>
#         │   ├── <__main__.TreeNode object at 0x000001F4DC055A48>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DBC86308>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DC1555C8>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DC1559C8>
#         │   │   └── <__main__.TreeNode object at 0x000001F4DC155888>
#         │   │       ├── <__main__.TreeNode object at 0x000001F4DBFF4808>
#         │   │       └── <__main__.TreeNode object at 0x000001F4DBFF4448>
#         │   ├── <__main__.TreeNode object at 0x000001F4DC155488>
#         │   ├── <__main__.TreeNode object at 0x000001F4DB981688>
#         │   └── <__main__.TreeNode object at 0x000001F4DB981848>
#         ├── <__main__.TreeNode object at 0x000001F4DC13FD08>
#         ├── <__main__.TreeNode object at 0x000001F4DC13FB08>
#         └── <__main__.TreeNode object at 0x000001F4DC153948>
#             ├── <__main__.TreeNode object at 0x000001F4DC055588>
#             ├── <__main__.TreeNode object at 0x000001F4DC0554C8>
#             ├── <__main__.TreeNode object at 0x000001F4DC132488>
#             └── <__main__.TreeNode object at 0x000001F4DC055088>
#                 ├── <__main__.TreeNode object at 0x000001F4DBC86E08>
#                 ├── <__main__.TreeNode object at 0x000001F4DBC86088>
#                 ├── <__main__.TreeNode object at 0x000001F4DBC7A688>
#                 └── <__main__.TreeNode object at 0x000001F4DB71CF88>
#
# Decision Tree 3
# <__main__.TreeNode object at 0x000001F4DBFC6648>
# ├── <__main__.TreeNode object at 0x000001F4DBB995C8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE4ED08>
# │   ├── <__main__.TreeNode object at 0x000001F4DB47C108>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB5C5448>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBCEDFC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBCED548>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBCEDD48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBCEDC88>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBE17208>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBE17488>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBE175C8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBE17AC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBC6B308>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB709408>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB709608>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE17F08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEFE648>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEFE148>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBEFEB88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE17A88>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBE17C08>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBEFE848>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBEFE448>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBEFED88>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBEFE1C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB93B4C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBEF8E88>
# │   ├── <__main__.TreeNode object at 0x000001F4DA404848>
# │   └── <__main__.TreeNode object at 0x000001F4DBAB4108>
# ├── <__main__.TreeNode object at 0x000001F4DB6492C8>
# │   ├── <__main__.TreeNode object at 0x000001F4DB7B4908>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBC68288>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBB72288>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBCEE3C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEC0C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFECF88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEFEE08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEFE808>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEE2288>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBEE2648>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF18948>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBE178C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBE0BE48>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBFECE88>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBEE2048>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBEE2C08>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBEE2088>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DBEE2308>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC01B948>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB709648>
# │   │       └── <__main__.TreeNode object at 0x000001F4DB709BC8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBA8D808>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBDFC088>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEF7508>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEF70C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEE2248>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEE2EC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEE2E48>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBEE2448>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBF037C8>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DBDB4408>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEF7E88>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBEF7888>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBEE2E88>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBEE2188>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBEE2A08>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBEE2948>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBC6BE48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB9881C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB709248>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEE25C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEE2988>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEE2FC8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBEE2A88>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBF1C888>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DBF1CF48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEF7348>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBEF7608>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBF18E48>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBF18708>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBEF7748>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBEF72C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBF03648>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBF03108>
# │   │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBF1C488>
# │   │       │   │   └── <__main__.TreeNode object at 0x000001F4DBF1C348>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DC08BD88>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DBEE2108>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB747108>
# │   │       └── <__main__.TreeNode object at 0x000001F4DBDB42C8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DC12B708>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DB703348>
# │   │           │   ├── <__main__.TreeNode object at 0x000001F4DBF1FEC8>
# │   │           │   └── <__main__.TreeNode object at 0x000001F4DBF1F288>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBF03E48>
# │   │           └── <__main__.TreeNode object at 0x000001F4DBF1CD88>
# │   ├── <__main__.TreeNode object at 0x000001F4DBBD6308>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD76A08>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF18FC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBB100C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB703F48>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBBA0C48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBF2BF88>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBF1C288>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBF1C548>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBF1C708>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB71CBC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF03D08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF1C6C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF1CF08>
# ...
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBD1ED48>
# │   │       └── <__main__.TreeNode object at 0x000001F4DC0EB348>
# │   ├── <__main__.TreeNode object at 0x000001F4DB811748>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB907148>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBEBD708>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB668988>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB668588>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB6681C8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8E9288>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB8E9A88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB8CC988>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3AB148>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3AB1C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC154C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB89B888>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB89BC88>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBE60C88>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBAA4188>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DBAA44C8>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DC0EBBC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB6C4348>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC8A8C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC8AF88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDF1648>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC157C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB668EC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDBBCC8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA4C48>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBAA4FC8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB93E988>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBD26EC8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB907408>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBAA6A48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBAA6F08>
# │   │   │       │   ├── <__main__.TreeNode object at 0x000001F4DBAA4B48>
# │   │   │       │   └── <__main__.TreeNode object at 0x000001F4DBAA4288>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBDF1788>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB8EB848>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE0EEC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB93E348>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBC15508>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB885488>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB8853C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF3E548>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBF3E408>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBDE19C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3C0A88>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBC158C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB5A60C8>
# │   ├── <__main__.TreeNode object at 0x000001F4DBB512C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD1E948>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB907CC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB907908>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB907848>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA6B48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA6188>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA60C8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB885708>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB885AC8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBD26308>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB8DE148>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBC0BD48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFB1908>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFB1E48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8CC948>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8CCF88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8CCDC8>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBE49748>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DBE49488>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB614B88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0EB648>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBE0E4C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB8CC7C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBC8A4C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB8CC5C8>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DBD1E1C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB8EB108>
# │   │   └── <__main__.TreeNode object at 0x000001F4DB8EBFC8>
# │   └── <__main__.TreeNode object at 0x000001F4DB510808>
# │       ├── <__main__.TreeNode object at 0x000001F4DBE60288>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB8CCBC8>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB8CC908>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA40C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB885E08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB8851C8>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DB885748>
# │       │   │       ├── <__main__.TreeNode object at 0x000001F4DBE49148>
# │       │   │       └── <__main__.TreeNode object at 0x000001F4DBA68E88>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB614888>
# │       │   └── <__main__.TreeNode object at 0x000001F4DB614788>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBF3E288>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFB18C8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBFB1D08>
# │       │       └── <__main__.TreeNode object at 0x000001F4DBFB1988>
# │       ├── <__main__.TreeNode object at 0x000001F4DBD1E608>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBEBD848>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB668708>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB8CCD08>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB8CC408>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB8CC888>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DB8CCE08>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DBFB1448>
# │       │   └── <__main__.TreeNode object at 0x000001F4DBFB13C8>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DB8CCD48>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DB907E08>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DB907048>
# │       │       └── <__main__.TreeNode object at 0x000001F4DB907448>
# │       ├── <__main__.TreeNode object at 0x000001F4DBC8AD08>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DA3C0208>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB8CC788>
# │       │   ├── <__main__.TreeNode object at 0x000001F4DB8CC148>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB885A48>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DB885948>
# │       │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB91E988>
# │       │   │   │   └── <__main__.TreeNode object at 0x000001F4DB91E8C8>
# │       │   │   ├── <__main__.TreeNode object at 0x000001F4DBA682C8>
# │       │   │   └── <__main__.TreeNode object at 0x000001F4DBA68F08>
# │       │   └── <__main__.TreeNode object at 0x000001F4DBF3EF88>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBE49D08>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBE49208>
# │       │       ├── <__main__.TreeNode object at 0x000001F4DBE494C8>
# │       │       └── <__main__.TreeNode object at 0x000001F4DBE49108>
# │       └── <__main__.TreeNode object at 0x000001F4C6525608>
# ├── <__main__.TreeNode object at 0x000001F4DBD08888>
# │   ├── <__main__.TreeNode object at 0x000001F4DC003608>
# │   ├── <__main__.TreeNode object at 0x000001F4DBFB12C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB93EB08>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBEBD608>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB885D08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA4D08>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8CC648>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8CCEC8>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB8CC1C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA4EC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA4848>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBAA4D48>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBD260C8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8EBE48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8EBD88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB91E1C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB91E808>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB91E748>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB91E308>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBA68CC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB91E648>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB7EC9C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB7EC148>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB7EC0C8>
# │   │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBFEA788>
# │   │   │   │       └── <__main__.TreeNode object at 0x000001F4DBFEAB88>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBE496C8>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBD26608>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DC0EB408>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DB91E5C8>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DB91E248>
# │   │       │   ├── <__main__.TreeNode object at 0x000001F4DB91EE88>
# │   │       │   └── <__main__.TreeNode object at 0x000001F4DBAA4448>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DB91E2C8>
# │   │       ├── <__main__.TreeNode object at 0x000001F4DBAA65C8>
# │   │       └── <__main__.TreeNode object at 0x000001F4DBAA6A88>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBAA4048>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBAA45C8>
# │   │           ├── <__main__.TreeNode object at 0x000001F4DBAA4408>
# │   │           └── <__main__.TreeNode object at 0x000001F4DBAA4648>
# │   │               ├── <__main__.TreeNode object at 0x000001F4DBFEA888>
# │   │               ├── <__main__.TreeNode object at 0x000001F4DBFEAE08>
# │   │               ├── <__main__.TreeNode object at 0x000001F4DB609588>
# │   │               └── <__main__.TreeNode object at 0x000001F4DB609188>
# │   ├── <__main__.TreeNode object at 0x000001F4DBE60608>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA2E88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD1E588>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD1EF48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBD1E908>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DBD1ECC8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DB91E688>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA6FC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA69C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEAAC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEA248>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC010308>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC010E48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB609948>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB609BC8>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DA3C0548>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB7EC5C8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB7EC088>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC010448>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC010048>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBAA4508>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DB885508>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB8858C8>
# │   │   ├── <__main__.TreeNode object at 0x000001F4DBDF1A88>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB8E9A48>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBF3EB88>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEAD88>
# │   │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC0101C8>
# │   │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC010AC8>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC010A48>
# │   │   │   │   ├── <__main__.TreeNode object at 0x000001F4DC010208>
# │   │   │   │   └── <__main__.TreeNode object at 0x000001F4DC010288>
# │   │   │   ├── <__main__.TreeNode object at 0x000001F4DB668188>
# │   │   │   └── <__main__.TreeNode object at 0x000001F4DB6687C8>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB609F48>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DB609E88>
# │   │   │       │   ├── <__main__.TreeNode object at 0x000001F4DB67F708>
# │   │   │       │   └── <__main__.TreeNode object at 0x000001F4DB67F908>
# │   │   │       ├── <__main__.TreeNode object at 0x000001F4DBE49D88>
# │   │   │       └── <__main__.TreeNode object at 0x000001F4DB8CCB08>
# │   │   └── <__main__.TreeNode object at 0x000001F4DBE0E308>
# │   └── <__main__.TreeNode object at 0x000001F4DBAA2A08>
# └── <__main__.TreeNode object at 0x000001F4DBF796C8>
#     ├── <__main__.TreeNode object at 0x000001F4DBDD0C88>
#     ├── <__main__.TreeNode object at 0x000001F4DBC0BEC8>
#     ├── <__main__.TreeNode object at 0x000001F4DBE59788>
#     │   ├── <__main__.TreeNode object at 0x000001F4DBFC34C8>
#     │   ├── <__main__.TreeNode object at 0x000001F4DBAAC608>
#     │   ├── <__main__.TreeNode object at 0x000001F4DBD1E508>
#     │   └── <__main__.TreeNode object at 0x000001F4DBD1EB08>
#     └── <__main__.TreeNode object at 0x000001F4DBFC3C88>
#         ├── <__main__.TreeNode object at 0x000001F4DBD1E208>
#         │   ├── <__main__.TreeNode object at 0x000001F4DB609C88>
#         │   ├── <__main__.TreeNode object at 0x000001F4DB609AC8>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEA148>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEA108>
#         │   │   ├── <__main__.TreeNode object at 0x000001F4DBFEA748>
#         │   │   └── <__main__.TreeNode object at 0x000001F4DBFEAA88>
#         │   ├── <__main__.TreeNode object at 0x000001F4DBAA4708>
#         │   └── <__main__.TreeNode object at 0x000001F4DBAA4588>
#         ├── <__main__.TreeNode object at 0x000001F4DB8E9FC8>
#         ├── <__main__.TreeNode object at 0x000001F4DB8E9DC8>
#         └── <__main__.TreeNode object at 0x000001F4DBC15BC8>
#             ├── <__main__.TreeNode object at 0x000001F4DB7ECA88>
#             ├── <__main__.TreeNode object at 0x000001F4DB7ECF08>
#             ├── <__main__.TreeNode object at 0x000001F4DB7ECD48>
#             └── <__main__.TreeNode object at 0x000001F4DB7EC788>
#                 ├── <__main__.TreeNode object at 0x000001F4DBFEA408>
#                 ├── <__main__.TreeNode object at 0x000001F4DB67F8C8>
#                 ├── <__main__.TreeNode object at 0x000001F4DB67FB88>
#                 └── <__main__.TreeNode object at 0x000001F4DB67FEC8>

# %%
img = load_img(test_path + 'cap.jpg')
print(get_img_class(img, rforest, minimum_purity))
# test correct
# Out:
# cap

# %%
img = load_img(test_path + 'cap2.jpg')
print(get_img_class(img, rforest, minimum_purity))
# test false
# Out:
# tulis

# %%
img = load_img(test_path + 'tulis.jpg')
print(get_img_class(img, rforest, minimum_purity))
# test correct
# Out:
# tulis
